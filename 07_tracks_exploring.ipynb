# %% [markdown]
# # Tracks Exploring
#
# ## Imports

# %%
import sqlite3
import pandas as pd

# %%
# Load the 'artists' table into a DataFrame
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file"""
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print("Connected to database")
        return True, conn
    except sqlite3.Error as e:
        print(f"Failed to connect: {e}")
        return False, None

# path to database file
status, conn  = create_connection("playlist_analysis.db")

if status:
    df_tracks = pd.read_sql_query("SELECT * FROM tracks;", conn)
else:
    print("Failed to establish a connection.")

# Display first few rows of the DataFrame to get an overview
df_tracks.head()
# Out:
# Connected to database
#                                   t_uri  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                                        t_name  t_duration_ms  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)         226863
# 1                                       Toxic         198800
# 2                               Crazy In Love         235933
# 3                              Rock Your Body         267266
# 4                                It Wasn't Me         227600
#
#                               artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
#
#                               album_uri  popularity  explicit  \
# 0  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K        67.0       1.0
# 1  spotify:album:0z7pVBGOD7HCIB7S8eLkLI        81.0       0.0
# 2  spotify:album:25hVFAxTlDvXbx2X2QkUkE        20.0       0.0
# 3  spotify:album:6QPkyl04rXwTGlGlcYaRoW        76.0       0.0
# 4  spotify:album:6NmFmPX56pcLBOFMhIiKvF         0.0       0.0
#
#                                          preview_url last_updated
# 0  https://p.scdn.co/mp3-preview/253a76c453026570...         None
# 1  https://p.scdn.co/mp3-preview/6de2791f84c1d637...         None
# 2  https://p.scdn.co/mp3-preview/bcd82e2e27606ec0...         None
# 3  https://p.scdn.co/mp3-preview/a4cdd210220f23d3...         None
# 4                                               None         None

# %%
missing = df_tracks.isnull().sum()
print(missing)
# Out:
# t_uri                 0
# t_name                0
# t_duration_ms         0
# artist_uri            0
# album_uri             0
# popularity           38
# explicit             38
# preview_url      153627
# last_updated     297900
# dtype: int64

# %%
import requests
import time
import json
import sqlite3
from datetime import datetime

# Create a connection to the database
def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except sqlite3.Error as e:
        print(e)
        return None
    
def alter_tracks_table(conn):
    try:
        cur = conn.cursor()
        cur.execute("ALTER TABLE tracks ADD COLUMN last_updated TEXT;")
        conn.commit()
        print("Tracks table altered successfully. Added column last_updated.")
    except sqlite3.Error as e:
        print(f"SQL error: {e}")

# Get all track URIs from the database
def get_all_track_uris(conn):
    cur = conn.cursor()
    cur.execute("SELECT t_uri FROM tracks;")
    return cur.fetchall()

# Create Spotify access token
def get_spotify_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_response = requests.post(auth_url, {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    })
    auth_response_data = auth_response.json()
    return auth_response_data['access_token'], auth_response_data['expires_in']

# Check if the token is about to expire
def is_token_expired(token_time, expires_in):
    current_time = time.time()
    return current_time - token_time >= expires_in - 10  # 10 seconds buffer

# Update track info in the database
def update_track_info(conn, track_uris, access_token):
    headers = {'Authorization': f'Bearer {access_token}'}
    track_ids = [uri.split(":")[-1] for uri in track_uris]
    
    r = requests.get(f"https://api.spotify.com/v1/tracks?ids={','.join(track_ids)}", headers=headers)
    
    # Handle rate limiting
    if r.status_code == 429:
        retry_after = int(r.headers.get('Retry-After', 60))  # Default to 60 seconds if header is missing
        print(f"Rate limit exceeded. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        update_track_info(conn, track_uris, access_token)  # Recursive retry
    
    # Handle other status codes
    
    elif r.status_code != 200:
        print(f"Failed to update tracks : Code: {r.status_code} : {r.text}")
        return
    
    # Update the database
    else:
        tracks_data = r.json()['tracks']
        cur = conn.cursor()
        
        for track_data in tracks_data:
            if track_data is None:
                print("Skipping None track data")
                continue
                
            track_uri = f"spotify:track:{track_data['id']}"
            popularity = track_data.get('popularity', None)
            explicit = track_data.get('explicit', None)
            preview_url = track_data.get('preview_url', None)

        cur.execute("UPDATE tracks SET popularity = ?, explicit = ?, preview_url = ?, last_updated = ? WHERE t_uri = ?",
            (popularity, explicit, preview_url, datetime.now().strftime('%Y-%m-%d %H:%M:%S'), track_uri))


        conn.commit()
        print(f"Status code for batch: {r.status_code}")


# Main function
if __name__ == '__main__':
    # Initialize
    conn = create_connection('playlist_analysis.db')
    client_id = 'your_client_id'
    client_secret = 'your_client_secret'
    access_token, expires_in = get_spotify_access_token(client_id, client_secret)
    token_time = time.time()  # Store the current time

    # Add new columns to the tracks table
    alter_tracks_table(conn)

    # Get all track URIs
    all_track_uris = get_all_track_uris(conn)
    total_tracks = len(all_track_uris)
    print(f"Total tracks to update: {total_tracks}")
    
    
    # Initialize rate limiting variables
    rate_limit_window = 25  # seconds
    max_requests = 20  # Maximum number of requests in rate_limit_window
    request_times = []

    # Update tracks in batches of 50
    for i in range(0, len(all_track_uris), 50):
        batch = all_track_uris[i:i + 50]

        # Check if the token is about to expire
        if is_token_expired(token_time, expires_in):
            print("Refreshing token...")
            access_token, expires_in = get_spotify_access_token(client_id, client_secret)
            token_time = time.time()

        # Check rate limit
        current_time = time.time()
        request_times = [t for t in request_times if current_time - t < rate_limit_window]
        if len(request_times) >= max_requests:
            sleep_time = rate_limit_window - (current_time - min(request_times))
            print(f"Rate limit reached. Sleeping for {sleep_time:.2f} seconds.")
            time.sleep(sleep_time)

        update_track_info(conn, [uri[0] for uri in batch], access_token)
        print(f"Successfully updated track info for batch {i} to {i+49}")

        time.sleep(0.2)  # to respect rate limits
    
    conn.close()
# Out:
# Tracks table altered successfully. Added column last_updated.
# Total tracks to update: 301546
# Status code for batch: 200
# Successfully updated track info for batch 0 to 49
# Status code for batch: 200
# Successfully updated track info for batch 50 to 99
# Status code for batch: 200
# Successfully updated track info for batch 100 to 149
# Status code for batch: 200
# Successfully updated track info for batch 150 to 199
# Status code for batch: 200
# Successfully updated track info for batch 200 to 249
# Status code for batch: 200
# Successfully updated track info for batch 250 to 299
# Status code for batch: 200
# Successfully updated track info for batch 300 to 349
# Status code for batch: 200
# Successfully updated track info for batch 350 to 399
# Status code for batch: 200
# Successfully updated track info for batch 400 to 449
# Status code for batch: 200
# Successfully updated track info for batch 450 to 499
# Status code for batch: 200
# Successfully updated track info for batch 500 to 549
# Status code for batch: 200
# Successfully updated track info for batch 550 to 599
# Status code for batch: 200
# Successfully updated track info for batch 600 to 649
# Status code for batch: 200
# Successfully updated track info for batch 650 to 699
# Status code for batch: 200
# Successfully updated track info for batch 700 to 749
# Status code for batch: 200
# Successfully updated track info for batch 750 to 799
# Status code for batch: 200
# Successfully updated track info for batch 800 to 849
# Status code for batch: 200
# Successfully updated track info for batch 850 to 899
# Status code for batch: 200
# Successfully updated track info for batch 900 to 949
# Status code for batch: 200
# Successfully updated track info for batch 950 to 999
# Status code for batch: 200
# Successfully updated track info for batch 1000 to 1049
# Status code for batch: 200
# Successfully updated track info for batch 1050 to 1099
# Status code for batch: 200
# Successfully updated track info for batch 1100 to 1149
# Status code for batch: 200
# Successfully updated track info for batch 1150 to 1199
# Status code for batch: 200
# Successfully updated track info for batch 1200 to 1249
# Status code for batch: 200
# Successfully updated track info for batch 1250 to 1299
# Status code for batch: 200
# Successfully updated track info for batch 1300 to 1349
# Status code for batch: 200
# Successfully updated track info for batch 1350 to 1399
# Status code for batch: 200
# Successfully updated track info for batch 1400 to 1449
# Status code for batch: 200
# Successfully updated track info for batch 1450 to 1499
# Status code for batch: 200
# Successfully updated track info for batch 1500 to 1549
# Status code for batch: 200
# Successfully updated track info for batch 1550 to 1599
# Status code for batch: 200
# Successfully updated track info for batch 1600 to 1649
# Status code for batch: 200
# Successfully updated track info for batch 1650 to 1699
# Status code for batch: 200
# Successfully updated track info for batch 1700 to 1749
# Status code for batch: 200
# Successfully updated track info for batch 1750 to 1799
# Status code for batch: 200
# Successfully updated track info for batch 1800 to 1849
# Status code for batch: 200
# Successfully updated track info for batch 1850 to 1899
# Status code for batch: 200
# Successfully updated track info for batch 1900 to 1949
# Status code for batch: 200
# Successfully updated track info for batch 1950 to 1999
# Status code for batch: 200
# Successfully updated track info for batch 2000 to 2049
# Status code for batch: 200
# Successfully updated track info for batch 2050 to 2099
# Status code for batch: 200
# Successfully updated track info for batch 2100 to 2149
# Status code for batch: 200
# Successfully updated track info for batch 2150 to 2199
# Status code for batch: 200
# Successfully updated track info for batch 2200 to 2249
# Status code for batch: 200
# Successfully updated track info for batch 2250 to 2299
# Status code for batch: 200
# Successfully updated track info for batch 2300 to 2349
# Status code for batch: 200
# Successfully updated track info for batch 2350 to 2399
# Status code for batch: 200
# Successfully updated track info for batch 2400 to 2449
# Status code for batch: 200
# Successfully updated track info for batch 2450 to 2499
# Status code for batch: 200
# Successfully updated track info for batch 2500 to 2549
# Status code for batch: 200
# Successfully updated track info for batch 2550 to 2599
# Status code for batch: 200
# Successfully updated track info for batch 2600 to 2649
# Status code for batch: 200
# Successfully updated track info for batch 2650 to 2699
# Status code for batch: 200
# Successfully updated track info for batch 2700 to 2749
# Status code for batch: 200
# Successfully updated track info for batch 2750 to 2799
# Status code for batch: 200
# Successfully updated track info for batch 2800 to 2849
# Status code for batch: 200
# Successfully updated track info for batch 2850 to 2899
# Status code for batch: 200
# Successfully updated track info for batch 2900 to 2949
# Status code for batch: 200
# Successfully updated track info for batch 2950 to 2999
# Status code for batch: 200
# Successfully updated track info for batch 3000 to 3049
# Status code for batch: 200
# Successfully updated track info for batch 3050 to 3099
# Status code for batch: 200
# Successfully updated track info for batch 3100 to 3149
# Status code for batch: 200
# Successfully updated track info for batch 3150 to 3199
# Status code for batch: 200
# Successfully updated track info for batch 3200 to 3249
# Status code for batch: 200
# Successfully updated track info for batch 3250 to 3299
# Status code for batch: 200
# Successfully updated track info for batch 3300 to 3349
# Status code for batch: 200
# Successfully updated track info for batch 3350 to 3399
# Status code for batch: 200
# Successfully updated track info for batch 3400 to 3449
# Status code for batch: 200
# Successfully updated track info for batch 3450 to 3499
# Status code for batch: 200
# Successfully updated track info for batch 3500 to 3549
# Status code for batch: 200
# Successfully updated track info for batch 3550 to 3599
# Status code for batch: 200
# Successfully updated track info for batch 3600 to 3649
# Status code for batch: 200
# Successfully updated track info for batch 3650 to 3699
# Status code for batch: 200
# Successfully updated track info for batch 3700 to 3749
# Status code for batch: 200
# Successfully updated track info for batch 3750 to 3799
# Status code for batch: 200
# Successfully updated track info for batch 3800 to 3849
# Status code for batch: 200
# Successfully updated track info for batch 3850 to 3899
# Status code for batch: 200
# Successfully updated track info for batch 3900 to 3949
# Status code for batch: 200
# Successfully updated track info for batch 3950 to 3999
# Status code for batch: 200
# Successfully updated track info for batch 4000 to 4049
# Status code for batch: 200
# Successfully updated track info for batch 4050 to 4099
# Status code for batch: 200
# Successfully updated track info for batch 4100 to 4149
# Status code for batch: 200
# Successfully updated track info for batch 4150 to 4199
# Status code for batch: 200
# Successfully updated track info for batch 4200 to 4249
# Status code for batch: 200
# Successfully updated track info for batch 4250 to 4299
# Status code for batch: 200
# Successfully updated track info for batch 4300 to 4349
# Status code for batch: 200
# Successfully updated track info for batch 4350 to 4399
# Status code for batch: 200
# Successfully updated track info for batch 4400 to 4449
# Status code for batch: 200
# Successfully updated track info for batch 4450 to 4499
# Status code for batch: 200
# Successfully updated track info for batch 4500 to 4549
# Status code for batch: 200
# Successfully updated track info for batch 4550 to 4599
# Status code for batch: 200
# Successfully updated track info for batch 4600 to 4649
# Status code for batch: 200
# Successfully updated track info for batch 4650 to 4699
# Status code for batch: 200
# Successfully updated track info for batch 4700 to 4749
# Status code for batch: 200
# Successfully updated track info for batch 4750 to 4799
# Status code for batch: 200
# Successfully updated track info for batch 4800 to 4849
# Status code for batch: 200
# Successfully updated track info for batch 4850 to 4899
# Status code for batch: 200
# Successfully updated track info for batch 4900 to 4949
# Status code for batch: 200
# Successfully updated track info for batch 4950 to 4999
# Status code for batch: 200
# Successfully updated track info for batch 5000 to 5049
# Status code for batch: 200
# Successfully updated track info for batch 5050 to 5099
# Status code for batch: 200
# Successfully updated track info for batch 5100 to 5149
# Status code for batch: 200
# Successfully updated track info for batch 5150 to 5199
# Status code for batch: 200
# Successfully updated track info for batch 5200 to 5249
# Status code for batch: 200
# Successfully updated track info for batch 5250 to 5299
# Status code for batch: 200
# Successfully updated track info for batch 5300 to 5349
# Status code for batch: 200
# Successfully updated track info for batch 5350 to 5399
# Status code for batch: 200
# Successfully updated track info for batch 5400 to 5449
# Status code for batch: 200
# Successfully updated track info for batch 5450 to 5499
# Status code for batch: 200
# Successfully updated track info for batch 5500 to 5549
# Status code for batch: 200
# Successfully updated track info for batch 5550 to 5599
# Status code for batch: 200
# Successfully updated track info for batch 5600 to 5649
# Status code for batch: 200
# Successfully updated track info for batch 5650 to 5699
# Status code for batch: 200
# Successfully updated track info for batch 5700 to 5749
# Status code for batch: 200
# Successfully updated track info for batch 5750 to 5799
# Status code for batch: 200
# Successfully updated track info for batch 5800 to 5849
# Status code for batch: 200
# Successfully updated track info for batch 5850 to 5899
# Status code for batch: 200
# Successfully updated track info for batch 5900 to 5949
# Status code for batch: 200
# Successfully updated track info for batch 5950 to 5999
# Status code for batch: 200
# Successfully updated track info for batch 6000 to 6049
# Status code for batch: 200
# Successfully updated track info for batch 6050 to 6099
# Status code for batch: 200
# Successfully updated track info for batch 6100 to 6149
# Status code for batch: 200
# Successfully updated track info for batch 6150 to 6199
# Status code for batch: 200
# Successfully updated track info for batch 6200 to 6249
# Status code for batch: 200
# Successfully updated track info for batch 6250 to 6299
# Status code for batch: 200
# Successfully updated track info for batch 6300 to 6349
# Status code for batch: 200
# Successfully updated track info for batch 6350 to 6399
# Status code for batch: 200
# Successfully updated track info for batch 6400 to 6449
# Status code for batch: 200
# Successfully updated track info for batch 6450 to 6499
# Status code for batch: 200
# Successfully updated track info for batch 6500 to 6549
# Status code for batch: 200
# Successfully updated track info for batch 6550 to 6599
# Status code for batch: 200
# Successfully updated track info for batch 6600 to 6649
# Status code for batch: 200
# Successfully updated track info for batch 6650 to 6699
# Status code for batch: 200
# Successfully updated track info for batch 6700 to 6749
# Status code for batch: 200
# Successfully updated track info for batch 6750 to 6799
# Status code for batch: 200
# Successfully updated track info for batch 6800 to 6849
# Status code for batch: 200
# Successfully updated track info for batch 6850 to 6899
# Status code for batch: 200
# Successfully updated track info for batch 6900 to 6949
# Status code for batch: 200
# Successfully updated track info for batch 6950 to 6999
# Status code for batch: 200
# Successfully updated track info for batch 7000 to 7049
# Status code for batch: 200
# Successfully updated track info for batch 7050 to 7099
# Status code for batch: 200
# Successfully updated track info for batch 7100 to 7149
# Status code for batch: 200
# Successfully updated track info for batch 7150 to 7199
# Status code for batch: 200
# Successfully updated track info for batch 7200 to 7249
# Status code for batch: 200
# Successfully updated track info for batch 7250 to 7299
# Status code for batch: 200
# Successfully updated track info for batch 7300 to 7349
# Status code for batch: 200
# Successfully updated track info for batch 7350 to 7399
# Status code for batch: 200
# Successfully updated track info for batch 7400 to 7449
# Status code for batch: 200
# Successfully updated track info for batch 7450 to 7499
# Status code for batch: 200
# Successfully updated track info for batch 7500 to 7549
# Status code for batch: 200
# Successfully updated track info for batch 7550 to 7599
# Status code for batch: 200
# Successfully updated track info for batch 7600 to 7649
# Status code for batch: 200
# Successfully updated track info for batch 7650 to 7699
# Status code for batch: 200
# Successfully updated track info for batch 7700 to 7749
# Status code for batch: 200
# Successfully updated track info for batch 7750 to 7799
# Status code for batch: 200
# Successfully updated track info for batch 7800 to 7849
# Status code for batch: 200
# Successfully updated track info for batch 7850 to 7899
# Status code for batch: 200
# Successfully updated track info for batch 7900 to 7949
# Status code for batch: 200
# Successfully updated track info for batch 7950 to 7999
# Status code for batch: 200
# Successfully updated track info for batch 8000 to 8049
# Status code for batch: 200
# Successfully updated track info for batch 8050 to 8099
# Status code for batch: 200
# Successfully updated track info for batch 8100 to 8149
# Status code for batch: 200
# Successfully updated track info for batch 8150 to 8199
# Status code for batch: 200
# Successfully updated track info for batch 8200 to 8249
# Status code for batch: 200
# Successfully updated track info for batch 8250 to 8299
# Status code for batch: 200
# Successfully updated track info for batch 8300 to 8349
# Status code for batch: 200
# Successfully updated track info for batch 8350 to 8399
# Status code for batch: 200
# Successfully updated track info for batch 8400 to 8449
# Status code for batch: 200
# Successfully updated track info for batch 8450 to 8499
# Status code for batch: 200
# Successfully updated track info for batch 8500 to 8549
# Status code for batch: 200
# Successfully updated track info for batch 8550 to 8599
# Status code for batch: 200
# Successfully updated track info for batch 8600 to 8649
# Status code for batch: 200
# Successfully updated track info for batch 8650 to 8699
# Status code for batch: 200
# Successfully updated track info for batch 8700 to 8749
# Status code for batch: 200
# Successfully updated track info for batch 8750 to 8799
# Status code for batch: 200
# Successfully updated track info for batch 8800 to 8849
# Status code for batch: 200
# Successfully updated track info for batch 8850 to 8899
# Status code for batch: 200
# Successfully updated track info for batch 8900 to 8949
# Status code for batch: 200
# Successfully updated track info for batch 8950 to 8999
# Status code for batch: 200
# Successfully updated track info for batch 9000 to 9049
# Status code for batch: 200
# Successfully updated track info for batch 9050 to 9099
# Status code for batch: 200
# Successfully updated track info for batch 9100 to 9149
# Status code for batch: 200
# Successfully updated track info for batch 9150 to 9199
# Status code for batch: 200
# Successfully updated track info for batch 9200 to 9249
# Status code for batch: 200
# Successfully updated track info for batch 9250 to 9299
# Status code for batch: 200
# Successfully updated track info for batch 9300 to 9349
# Status code for batch: 200
# Successfully updated track info for batch 9350 to 9399
# Status code for batch: 200
# Successfully updated track info for batch 9400 to 9449
# Status code for batch: 200
# Successfully updated track info for batch 9450 to 9499
# Status code for batch: 200
# Successfully updated track info for batch 9500 to 9549
# Status code for batch: 200
# Successfully updated track info for batch 9550 to 9599
# Status code for batch: 200
# Successfully updated track info for batch 9600 to 9649
# Status code for batch: 200
# Successfully updated track info for batch 9650 to 9699
# Status code for batch: 200
# Successfully updated track info for batch 9700 to 9749
# Status code for batch: 200
# Successfully updated track info for batch 9750 to 9799
# Status code for batch: 200
# Successfully updated track info for batch 9800 to 9849
# Status code for batch: 200
# Successfully updated track info for batch 9850 to 9899
# Status code for batch: 200
# Successfully updated track info for batch 9900 to 9949
# Status code for batch: 200
# Successfully updated track info for batch 9950 to 9999
# Status code for batch: 200
# Successfully updated track info for batch 10000 to 10049
# Status code for batch: 200
# Successfully updated track info for batch 10050 to 10099
# Status code for batch: 200
# Successfully updated track info for batch 10100 to 10149
# Status code for batch: 200
# Successfully updated track info for batch 10150 to 10199
# Status code for batch: 200
# Successfully updated track info for batch 10200 to 10249
# Status code for batch: 200
# Successfully updated track info for batch 10250 to 10299
# Status code for batch: 200
# Successfully updated track info for batch 10300 to 10349
# Status code for batch: 200
# Successfully updated track info for batch 10350 to 10399
# Status code for batch: 200
# Successfully updated track info for batch 10400 to 10449
# Status code for batch: 200
# Successfully updated track info for batch 10450 to 10499
# Status code for batch: 200
# Successfully updated track info for batch 10500 to 10549
# Status code for batch: 200
# Successfully updated track info for batch 10550 to 10599
# Status code for batch: 200
# Successfully updated track info for batch 10600 to 10649
# Status code for batch: 200
# Successfully updated track info for batch 10650 to 10699
# Status code for batch: 200
# Successfully updated track info for batch 10700 to 10749
# Status code for batch: 200
# Successfully updated track info for batch 10750 to 10799
# Status code for batch: 200
# Successfully updated track info for batch 10800 to 10849
# Status code for batch: 200
# Successfully updated track info for batch 10850 to 10899
# Status code for batch: 200
# Successfully updated track info for batch 10900 to 10949
# Status code for batch: 200
# Successfully updated track info for batch 10950 to 10999
# Status code for batch: 200
# Successfully updated track info for batch 11000 to 11049
# Status code for batch: 200
# Successfully updated track info for batch 11050 to 11099
# Status code for batch: 200
# Successfully updated track info for batch 11100 to 11149
# Status code for batch: 200
# Successfully updated track info for batch 11150 to 11199
# Status code for batch: 200
# Successfully updated track info for batch 11200 to 11249
# Status code for batch: 200
# Successfully updated track info for batch 11250 to 11299
# Status code for batch: 200
# Successfully updated track info for batch 11300 to 11349
# Status code for batch: 200
# Successfully updated track info for batch 11350 to 11399
# Status code for batch: 200
# Successfully updated track info for batch 11400 to 11449
# Status code for batch: 200
# Successfully updated track info for batch 11450 to 11499
# Status code for batch: 200
# Successfully updated track info for batch 11500 to 11549
# Status code for batch: 200
# Successfully updated track info for batch 11550 to 11599
# Status code for batch: 200
# Successfully updated track info for batch 11600 to 11649
# Status code for batch: 200
# Successfully updated track info for batch 11650 to 11699
# Status code for batch: 200
# Successfully updated track info for batch 11700 to 11749
# Status code for batch: 200
# Successfully updated track info for batch 11750 to 11799
# Status code for batch: 200
# Successfully updated track info for batch 11800 to 11849
# Status code for batch: 200
# Successfully updated track info for batch 11850 to 11899
# Status code for batch: 200
# Successfully updated track info for batch 11900 to 11949
# Status code for batch: 200
# Successfully updated track info for batch 11950 to 11999
# Status code for batch: 200
# Successfully updated track info for batch 12000 to 12049
# Status code for batch: 200
# Successfully updated track info for batch 12050 to 12099
# Status code for batch: 200
# Successfully updated track info for batch 12100 to 12149
# Status code for batch: 200
# Successfully updated track info for batch 12150 to 12199
# Status code for batch: 200
# Successfully updated track info for batch 12200 to 12249
# Status code for batch: 200
# Successfully updated track info for batch 12250 to 12299
# Status code for batch: 200
# Successfully updated track info for batch 12300 to 12349
# Status code for batch: 200
# Successfully updated track info for batch 12350 to 12399
# Status code for batch: 200
# Successfully updated track info for batch 12400 to 12449
# Status code for batch: 200
# Successfully updated track info for batch 12450 to 12499
# Skipping None track data
# Status code for batch: 200
# Successfully updated track info for batch 12500 to 12549
# Status code for batch: 200
# Successfully updated track info for batch 12550 to 12599
# Status code for batch: 200
# Successfully updated track info for batch 12600 to 12649
# Status code for batch: 200
# Successfully updated track info for batch 12650 to 12699
# Status code for batch: 200
# Successfully updated track info for batch 12700 to 12749
# Status code for batch: 200
# Successfully updated track info for batch 12750 to 12799
# Status code for batch: 200
# Successfully updated track info for batch 12800 to 12849
# Status code for batch: 200
# Successfully updated track info for batch 12850 to 12899
# Status code for batch: 200
# Successfully updated track info for batch 12900 to 12949
# Status code for batch: 200
# Successfully updated track info for batch 12950 to 12999
# Status code for batch: 200
# Successfully updated track info for batch 13000 to 13049
# Status code for batch: 200
# Successfully updated track info for batch 13050 to 13099
# Status code for batch: 200
# Successfully updated track info for batch 13100 to 13149
# Status code for batch: 200
# Successfully updated track info for batch 13150 to 13199
# Status code for batch: 200
# Successfully updated track info for batch 13200 to 13249
# Status code for batch: 200
# Successfully updated track info for batch 13250 to 13299
# Status code for batch: 200
# Successfully updated track info for batch 13300 to 13349
# Status code for batch: 200
# Successfully updated track info for batch 13350 to 13399
# Status code for batch: 200
# Successfully updated track info for batch 13400 to 13449
# Status code for batch: 200
# Successfully updated track info for batch 13450 to 13499
# Status code for batch: 200
# Successfully updated track info for batch 13500 to 13549
# Status code for batch: 200
# Successfully updated track info for batch 13550 to 13599
# Status code for batch: 200
# Successfully updated track info for batch 13600 to 13649
# Status code for batch: 200
# Successfully updated track info for batch 13650 to 13699
# Status code for batch: 200
# Successfully updated track info for batch 13700 to 13749
# Status code for batch: 200
# Successfully updated track info for batch 13750 to 13799
# Status code for batch: 200
# Successfully updated track info for batch 13800 to 13849
# Status code for batch: 200
# Successfully updated track info for batch 13850 to 13899
# Status code for batch: 200
# Successfully updated track info for batch 13900 to 13949
# Status code for batch: 200
# Successfully updated track info for batch 13950 to 13999
# Status code for batch: 200
# Successfully updated track info for batch 14000 to 14049
# Status code for batch: 200
# Successfully updated track info for batch 14050 to 14099
# Status code for batch: 200
# Successfully updated track info for batch 14100 to 14149
# Status code for batch: 200
# Successfully updated track info for batch 14150 to 14199
# Status code for batch: 200
# Successfully updated track info for batch 14200 to 14249
# Status code for batch: 200
# Successfully updated track info for batch 14250 to 14299
# Status code for batch: 200
# Successfully updated track info for batch 14300 to 14349
# Skipping None track data
# Status code for batch: 200
# Successfully updated track info for batch 14350 to 14399
# Status code for batch: 200
# Successfully updated track info for batch 14400 to 14449
# Status code for batch: 200
# Successfully updated track info for batch 14450 to 14499
# Status code for batch: 200
# Successfully updated track info for batch 14500 to 14549
# Status code for batch: 200
# Successfully updated track info for batch 14550 to 14599
# Status code for batch: 200
# Successfully updated track info for batch 14600 to 14649
# Status code for batch: 200
# Successfully updated track info for batch 14650 to 14699
# Status code for batch: 200
# Successfully updated track info for batch 14700 to 14749
# Status code for batch: 200
# Successfully updated track info for batch 14750 to 14799
# Status code for batch: 200
# Successfully updated track info for batch 14800 to 14849
# Status code for batch: 200
# Successfully updated track info for batch 14850 to 14899
# Status code for batch: 200
# Successfully updated track info for batch 14900 to 14949
# Status code for batch: 200
# Successfully updated track info for batch 14950 to 14999
# Status code for batch: 200
# Successfully updated track info for batch 15000 to 15049
# Status code for batch: 200
# Successfully updated track info for batch 15050 to 15099
# Status code for batch: 200
# Successfully updated track info for batch 15100 to 15149
# Status code for batch: 200
# Successfully updated track info for batch 15150 to 15199
# Status code for batch: 200
# Successfully updated track info for batch 15200 to 15249
# Status code for batch: 200
# Successfully updated track info for batch 15250 to 15299
# Status code for batch: 200
# Successfully updated track info for batch 15300 to 15349
# Status code for batch: 200
# Successfully updated track info for batch 15350 to 15399
# Status code for batch: 200
# Successfully updated track info for batch 15400 to 15449
# Status code for batch: 200
# Successfully updated track info for batch 15450 to 15499
# Status code for batch: 200
# Successfully updated track info for batch 15500 to 15549
# Status code for batch: 200
# Successfully updated track info for batch 15550 to 15599
# Status code for batch: 200
# Successfully updated track info for batch 15600 to 15649
# Status code for batch: 200
# Successfully updated track info for batch 15650 to 15699
# Status code for batch: 200
# Successfully updated track info for batch 15700 to 15749
# Status code for batch: 200
# Successfully updated track info for batch 15750 to 15799
# Status code for batch: 200
# Successfully updated track info for batch 15800 to 15849
# Status code for batch: 200
# Successfully updated track info for batch 15850 to 15899
# Status code for batch: 200
# Successfully updated track info for batch 15900 to 15949
# Status code for batch: 200
# Successfully updated track info for batch 15950 to 15999
# Status code for batch: 200
# Successfully updated track info for batch 16000 to 16049
# Status code for batch: 200
# Successfully updated track info for batch 16050 to 16099
# Status code for batch: 200
# Successfully updated track info for batch 16100 to 16149
# Status code for batch: 200
# Successfully updated track info for batch 16150 to 16199
# Status code for batch: 200
# Successfully updated track info for batch 16200 to 16249
# Status code for batch: 200
# Successfully updated track info for batch 16250 to 16299
# Status code for batch: 200
# Successfully updated track info for batch 16300 to 16349
# Status code for batch: 200
# Successfully updated track info for batch 16350 to 16399
# Status code for batch: 200
# Successfully updated track info for batch 16400 to 16449
# Status code for batch: 200
# Successfully updated track info for batch 16450 to 16499
# Status code for batch: 200
# Successfully updated track info for batch 16500 to 16549
# Status code for batch: 200
# Successfully updated track info for batch 16550 to 16599
# Status code for batch: 200
# Successfully updated track info for batch 16600 to 16649
# Status code for batch: 200
# Successfully updated track info for batch 16650 to 16699
# Status code for batch: 200
# Successfully updated track info for batch 16700 to 16749
# Status code for batch: 200
# Successfully updated track info for batch 16750 to 16799
# Status code for batch: 200
# Successfully updated track info for batch 16800 to 16849
# Status code for batch: 200
# Successfully updated track info for batch 16850 to 16899
# Status code for batch: 200
# Successfully updated track info for batch 16900 to 16949
# Status code for batch: 200
# Successfully updated track info for batch 16950 to 16999
# Status code for batch: 200
# Successfully updated track info for batch 17000 to 17049
# Status code for batch: 200
# Successfully updated track info for batch 17050 to 17099
# Status code for batch: 200
# Successfully updated track info for batch 17100 to 17149
# Status code for batch: 200
# Successfully updated track info for batch 17150 to 17199
# Status code for batch: 200
# Successfully updated track info for batch 17200 to 17249
# Status code for batch: 200
# Successfully updated track info for batch 17250 to 17299
# Status code for batch: 200
# Successfully updated track info for batch 17300 to 17349
# Status code for batch: 200
# Successfully updated track info for batch 17350 to 17399
# Status code for batch: 200
# Successfully updated track info for batch 17400 to 17449
# Status code for batch: 200
# Successfully updated track info for batch 17450 to 17499
# Status code for batch: 200
# Successfully updated track info for batch 17500 to 17549
# Status code for batch: 200
# Successfully updated track info for batch 17550 to 17599
# Status code for batch: 200
# Successfully updated track info for batch 17600 to 17649
# Status code for batch: 200
# Successfully updated track info for batch 17650 to 17699
# Status code for batch: 200
# Successfully updated track info for batch 17700 to 17749
# Status code for batch: 200
# Successfully updated track info for batch 17750 to 17799
# Status code for batch: 200
# Successfully updated track info for batch 17800 to 17849
# Status code for batch: 200
# Successfully updated track info for batch 17850 to 17899
# Status code for batch: 200
# Successfully updated track info for batch 17900 to 17949
# Status code for batch: 200
# Successfully updated track info for batch 17950 to 17999
# Status code for batch: 200
# Successfully updated track info for batch 18000 to 18049
# Status code for batch: 200
# Successfully updated track info for batch 18050 to 18099
# Status code for batch: 200
# Successfully updated track info for batch 18100 to 18149
# Status code for batch: 200
# Successfully updated track info for batch 18150 to 18199
# Status code for batch: 200
# Successfully updated track info for batch 18200 to 18249
# Status code for batch: 200
# Successfully updated track info for batch 18250 to 18299
# Status code for batch: 200
# Successfully updated track info for batch 18300 to 18349
# Status code for batch: 200
# Successfully updated track info for batch 18350 to 18399
# Status code for batch: 200
# Successfully updated track info for batch 18400 to 18449
# Status code for batch: 200
# Successfully updated track info for batch 18450 to 18499
# Status code for batch: 200
# Successfully updated track info for batch 18500 to 18549
# Status code for batch: 200
# Successfully updated track info for batch 18550 to 18599
# Status code for batch: 200
# Successfully updated track info for batch 18600 to 18649
# Status code for batch: 200
# Successfully updated track info for batch 18650 to 18699
# Status code for batch: 200
# Successfully updated track info for batch 18700 to 18749
# Status code for batch: 200
# Successfully updated track info for batch 18750 to 18799
# Status code for batch: 200
# Successfully updated track info for batch 18800 to 18849
# Status code for batch: 200
# Successfully updated track info for batch 18850 to 18899
# Status code for batch: 200
# Successfully updated track info for batch 18900 to 18949
# Status code for batch: 200
# Successfully updated track info for batch 18950 to 18999
# Status code for batch: 200
# Successfully updated track info for batch 19000 to 19049
# Status code for batch: 200
# Successfully updated track info for batch 19050 to 19099
# Status code for batch: 200
# Successfully updated track info for batch 19100 to 19149
# Status code for batch: 200
# Successfully updated track info for batch 19150 to 19199
# Status code for batch: 200
# Successfully updated track info for batch 19200 to 19249
# Status code for batch: 200
# Successfully updated track info for batch 19250 to 19299
# Status code for batch: 200
# Successfully updated track info for batch 19300 to 19349
# Status code for batch: 200
# Successfully updated track info for batch 19350 to 19399
# Status code for batch: 200
# Successfully updated track info for batch 19400 to 19449
# Status code for batch: 200
# Successfully updated track info for batch 19450 to 19499
# Status code for batch: 200
# Successfully updated track info for batch 19500 to 19549
# Status code for batch: 200
# Successfully updated track info for batch 19550 to 19599
# Status code for batch: 200
# Successfully updated track info for batch 19600 to 19649
# Status code for batch: 200
# Successfully updated track info for batch 19650 to 19699
# Status code for batch: 200
# Successfully updated track info for batch 19700 to 19749
# Status code for batch: 200
# Successfully updated track info for batch 19750 to 19799
# Status code for batch: 200
# Successfully updated track info for batch 19800 to 19849
# Status code for batch: 200
# Successfully updated track info for batch 19850 to 19899
# Status code for batch: 200
# Successfully updated track info for batch 19900 to 19949
# Status code for batch: 200
# Successfully updated track info for batch 19950 to 19999
# Status code for batch: 200
# Successfully updated track info for batch 20000 to 20049
# Status code for batch: 200
# Successfully updated track info for batch 20050 to 20099
# Status code for batch: 200
# Successfully updated track info for batch 20100 to 20149
# Status code for batch: 200
# Successfully updated track info for batch 20150 to 20199
# Status code for batch: 200
# Successfully updated track info for batch 20200 to 20249
# Status code for batch: 200
# Successfully updated track info for batch 20250 to 20299
# Status code for batch: 200
# Successfully updated track info for batch 20300 to 20349
# Status code for batch: 200
# Successfully updated track info for batch 20350 to 20399
# Status code for batch: 200
# Successfully updated track info for batch 20400 to 20449
# Status code for batch: 200
# Successfully updated track info for batch 20450 to 20499
# Status code for batch: 200
# Successfully updated track info for batch 20500 to 20549
# Status code for batch: 200
# Successfully updated track info for batch 20550 to 20599
# Status code for batch: 200
# Successfully updated track info for batch 20600 to 20649
# Status code for batch: 200
# Successfully updated track info for batch 20650 to 20699
# Status code for batch: 200
# Successfully updated track info for batch 20700 to 20749
# Status code for batch: 200
# Successfully updated track info for batch 20750 to 20799
# Status code for batch: 200
# Successfully updated track info for batch 20800 to 20849
# Status code for batch: 200
# Successfully updated track info for batch 20850 to 20899
# Status code for batch: 200
# Successfully updated track info for batch 20900 to 20949
# Status code for batch: 200
# Successfully updated track info for batch 20950 to 20999
# Status code for batch: 200
# Successfully updated track info for batch 21000 to 21049
# Status code for batch: 200
# Successfully updated track info for batch 21050 to 21099
# Status code for batch: 200
# Successfully updated track info for batch 21100 to 21149
# Status code for batch: 200
# Successfully updated track info for batch 21150 to 21199
# Status code for batch: 200
# Successfully updated track info for batch 21200 to 21249
# Status code for batch: 200
# Successfully updated track info for batch 21250 to 21299
# Status code for batch: 200
# Successfully updated track info for batch 21300 to 21349
# Status code for batch: 200
# Successfully updated track info for batch 21350 to 21399
# Status code for batch: 200
# Successfully updated track info for batch 21400 to 21449
# Status code for batch: 200
# Successfully updated track info for batch 21450 to 21499
# Status code for batch: 200
# Successfully updated track info for batch 21500 to 21549
# Status code for batch: 200
# Successfully updated track info for batch 21550 to 21599
# Status code for batch: 200
# Successfully updated track info for batch 21600 to 21649
# Status code for batch: 200
# Successfully updated track info for batch 21650 to 21699
# Status code for batch: 200
# Successfully updated track info for batch 21700 to 21749
# Status code for batch: 200
# Successfully updated track info for batch 21750 to 21799
# Status code for batch: 200
# Successfully updated track info for batch 21800 to 21849
# Status code for batch: 200
# Successfully updated track info for batch 21850 to 21899
# Status code for batch: 200
# Successfully updated track info for batch 21900 to 21949
# Status code for batch: 200
# Successfully updated track info for batch 21950 to 21999
# Status code for batch: 200
# Successfully updated track info for batch 22000 to 22049
# Status code for batch: 200
# Successfully updated track info for batch 22050 to 22099
# Status code for batch: 200
# Successfully updated track info for batch 22100 to 22149
# Status code for batch: 200
# Successfully updated track info for batch 22150 to 22199
# Status code for batch: 200
# Successfully updated track info for batch 22200 to 22249
# Status code for batch: 200
# Successfully updated track info for batch 22250 to 22299
# Status code for batch: 200
# Successfully updated track info for batch 22300 to 22349
# Status code for batch: 200
# Successfully updated track info for batch 22350 to 22399
# Status code for batch: 200
# Successfully updated track info for batch 22400 to 22449
# Status code for batch: 200
# Successfully updated track info for batch 22450 to 22499
# Status code for batch: 200
# Successfully updated track info for batch 22500 to 22549
# Status code for batch: 200
# Successfully updated track info for batch 22550 to 22599
# Status code for batch: 200
# Successfully updated track info for batch 22600 to 22649
# Status code for batch: 200
# Successfully updated track info for batch 22650 to 22699
# Status code for batch: 200
# Successfully updated track info for batch 22700 to 22749
# Status code for batch: 200
# Successfully updated track info for batch 22750 to 22799
# Status code for batch: 200
# Successfully updated track info for batch 22800 to 22849
# Status code for batch: 200
# Successfully updated track info for batch 22850 to 22899
# Status code for batch: 200
# Successfully updated track info for batch 22900 to 22949
# Status code for batch: 200
# Successfully updated track info for batch 22950 to 22999
# Status code for batch: 200
# Successfully updated track info for batch 23000 to 23049
# Status code for batch: 200
# Successfully updated track info for batch 23050 to 23099
# Status code for batch: 200
# Successfully updated track info for batch 23100 to 23149
# Status code for batch: 200
# Successfully updated track info for batch 23150 to 23199
# Status code for batch: 200
# Successfully updated track info for batch 23200 to 23249
# Status code for batch: 200
# Successfully updated track info for batch 23250 to 23299
# Status code for batch: 200
# Successfully updated track info for batch 23300 to 23349
# Status code for batch: 200
# Successfully updated track info for batch 23350 to 23399
# Status code for batch: 200
# Successfully updated track info for batch 23400 to 23449
# Status code for batch: 200
# Successfully updated track info for batch 23450 to 23499
# Status code for batch: 200
# Successfully updated track info for batch 23500 to 23549
# Status code for batch: 200
# Successfully updated track info for batch 23550 to 23599
# Status code for batch: 200
# Successfully updated track info for batch 23600 to 23649
# Status code for batch: 200
# Successfully updated track info for batch 23650 to 23699
# Status code for batch: 200
# Successfully updated track info for batch 23700 to 23749
# Status code for batch: 200
# Successfully updated track info for batch 23750 to 23799
# Status code for batch: 200
# Successfully updated track info for batch 23800 to 23849
# Status code for batch: 200
# Successfully updated track info for batch 23850 to 23899
# Status code for batch: 200
# Successfully updated track info for batch 23900 to 23949
# Status code for batch: 200
# Successfully updated track info for batch 23950 to 23999
# Status code for batch: 200
# Successfully updated track info for batch 24000 to 24049
# Status code for batch: 200
# Successfully updated track info for batch 24050 to 24099
# Status code for batch: 200
# Successfully updated track info for batch 24100 to 24149
# Status code for batch: 200
# Successfully updated track info for batch 24150 to 24199
# Status code for batch: 200
# Successfully updated track info for batch 24200 to 24249
# Status code for batch: 200
# Successfully updated track info for batch 24250 to 24299
# Status code for batch: 200
# Successfully updated track info for batch 24300 to 24349
# Status code for batch: 200
# Successfully updated track info for batch 24350 to 24399
# Status code for batch: 200
# Successfully updated track info for batch 24400 to 24449
# Status code for batch: 200
# Successfully updated track info for batch 24450 to 24499
# Status code for batch: 200
# Successfully updated track info for batch 24500 to 24549
# Status code for batch: 200
# Successfully updated track info for batch 24550 to 24599
# Status code for batch: 200
# Successfully updated track info for batch 24600 to 24649
# Status code for batch: 200
# Successfully updated track info for batch 24650 to 24699
# Status code for batch: 200
# Successfully updated track info for batch 24700 to 24749
# Status code for batch: 200
# Successfully updated track info for batch 24750 to 24799
# Status code for batch: 200
# Successfully updated track info for batch 24800 to 24849
# Status code for batch: 200
# Successfully updated track info for batch 24850 to 24899
# Status code for batch: 200
# Successfully updated track info for batch 24900 to 24949
# Status code for batch: 200
# Successfully updated track info for batch 24950 to 24999
# Status code for batch: 200
# Successfully updated track info for batch 25000 to 25049
# Status code for batch: 200
# Successfully updated track info for batch 25050 to 25099
# Status code for batch: 200
# Successfully updated track info for batch 25100 to 25149
# Status code for batch: 200
# Successfully updated track info for batch 25150 to 25199
# Status code for batch: 200
# Successfully updated track info for batch 25200 to 25249
# Status code for batch: 200
# Successfully updated track info for batch 25250 to 25299
# Status code for batch: 200
# Successfully updated track info for batch 25300 to 25349
# Status code for batch: 200
# Successfully updated track info for batch 25350 to 25399
# Status code for batch: 200
# Successfully updated track info for batch 25400 to 25449
# Status code for batch: 200
# Successfully updated track info for batch 25450 to 25499
# Status code for batch: 200
# Successfully updated track info for batch 25500 to 25549
# Status code for batch: 200
# Successfully updated track info for batch 25550 to 25599
# Status code for batch: 200
# Successfully updated track info for batch 25600 to 25649
# Status code for batch: 200
# Successfully updated track info for batch 25650 to 25699
# Status code for batch: 200
# Successfully updated track info for batch 25700 to 25749
# Status code for batch: 200
# Successfully updated track info for batch 25750 to 25799
# Status code for batch: 200
# Successfully updated track info for batch 25800 to 25849
# Status code for batch: 200
# Successfully updated track info for batch 25850 to 25899
# Skipping None track data
# Status code for batch: 200
# Successfully updated track info for batch 25900 to 25949
# Status code for batch: 200
# Successfully updated track info for batch 25950 to 25999
# Status code for batch: 200
# Successfully updated track info for batch 26000 to 26049
# Status code for batch: 200
# Successfully updated track info for batch 26050 to 26099
# Skipping None track data
# Status code for batch: 200
# Successfully updated track info for batch 26100 to 26149
# Status code for batch: 200
# Successfully updated track info for batch 26150 to 26199
# Status code for batch: 200
# Successfully updated track info for batch 26200 to 26249
# Status code for batch: 200
# Successfully updated track info for batch 26250 to 26299
# Status code for batch: 200
# Successfully updated track info for batch 26300 to 26349
# Status code for batch: 200
# Successfully updated track info for batch 26350 to 26399
# Status code for batch: 200
# Successfully updated track info for batch 26400 to 26449
# Status code for batch: 200
# Successfully updated track info for batch 26450 to 26499
# Status code for batch: 200
# Successfully updated track info for batch 26500 to 26549
# Status code for batch: 200
# Successfully updated track info for batch 26550 to 26599
# Status code for batch: 200
# Successfully updated track info for batch 26600 to 26649
# Status code for batch: 200
# Successfully updated track info for batch 26650 to 26699
# Status code for batch: 200
# Successfully updated track info for batch 26700 to 26749
# Status code for batch: 200
# Successfully updated track info for batch 26750 to 26799
# Status code for batch: 200
# Successfully updated track info for batch 26800 to 26849
# Status code for batch: 200
# Successfully updated track info for batch 26850 to 26899
# Status code for batch: 200
# Successfully updated track info for batch 26900 to 26949
# Status code for batch: 200
# Successfully updated track info for batch 26950 to 26999
# Status code for batch: 200
# Successfully updated track info for batch 27000 to 27049
# Status code for batch: 200
# Successfully updated track info for batch 27050 to 27099
# Status code for batch: 200
# Successfully updated track info for batch 27100 to 27149
# Status code for batch: 200
# Successfully updated track info for batch 27150 to 27199
# Status code for batch: 200
# Successfully updated track info for batch 27200 to 27249
# Status code for batch: 200
# Successfully updated track info for batch 27250 to 27299
# Status code for batch: 200
# Successfully updated track info for batch 27300 to 27349
# Status code for batch: 200
# Successfully updated track info for batch 27350 to 27399
# Status code for batch: 200
# Successfully updated track info for batch 27400 to 27449
# Status code for batch: 200
# Successfully updated track info for batch 27450 to 27499
# Status code for batch: 200
# Successfully updated track info for batch 27500 to 27549
# Status code for batch: 200
# Successfully updated track info for batch 27550 to 27599
# Status code for batch: 200
# Successfully updated track info for batch 27600 to 27649
# Status code for batch: 200
# Successfully updated track info for batch 27650 to 27699
# Status code for batch: 200
# Successfully updated track info for batch 27700 to 27749
# Status code for batch: 200
# Successfully updated track info for batch 27750 to 27799
# Status code for batch: 200
# Successfully updated track info for batch 27800 to 27849
# Status code for batch: 200
# Successfully updated track info for batch 27850 to 27899
# Status code for batch: 200
# Successfully updated track info for batch 27900 to 27949
# Status code for batch: 200
# Successfully updated track info for batch 27950 to 27999
# Status code for batch: 200
# Successfully updated track info for batch 28000 to 28049
# Status code for batch: 200
# Successfully updated track info for batch 28050 to 28099
# Status code for batch: 200
# Successfully updated track info for batch 28100 to 28149
# Status code for batch: 200
# Successfully updated track info for batch 28150 to 28199
# Status code for batch: 200
# Successfully updated track info for batch 28200 to 28249
# Status code for batch: 200
# Successfully updated track info for batch 28250 to 28299
# Status code for batch: 200
# Successfully updated track info for batch 28300 to 28349
# Status code for batch: 200
# Successfully updated track info for batch 28350 to 28399
# Status code for batch: 200
# Successfully updated track info for batch 28400 to 28449
# Status code for batch: 200
# Successfully updated track info for batch 28450 to 28499
# Status code for batch: 200
# Successfully updated track info for batch 28500 to 28549
# Status code for batch: 200
# Successfully updated track info for batch 28550 to 28599
# Status code for batch: 200
# Successfully updated track info for batch 28600 to 28649
# Status code for batch: 200
# Successfully updated track info for batch 28650 to 28699
# Status code for batch: 200
# ...
# Status code for batch: 200
# Successfully updated track info for batch 173050 to 173099
# Status code for batch: 200
# Successfully updated track info for batch 173100 to 173149
# Status code for batch: 200
# Successfully updated track info for batch 173150 to 173199
# Status code for batch: 200
# Successfully updated track info for batch 173200 to 173249
# Status code for batch: 200
# Successfully updated track info for batch 173250 to 173299
# Status code for batch: 200
# Successfully updated track info for batch 173300 to 173349
# Status code for batch: 200
# Successfully updated track info for batch 173350 to 173399
# Status code for batch: 200
# Successfully updated track info for batch 173400 to 173449
# Status code for batch: 200
# Successfully updated track info for batch 173450 to 173499
# Status code for batch: 200
# Successfully updated track info for batch 173500 to 173549
# Status code for batch: 200
# Successfully updated track info for batch 173550 to 173599
# Status code for batch: 200
# Successfully updated track info for batch 173600 to 173649
# Status code for batch: 200
# Successfully updated track info for batch 173650 to 173699
# Status code for batch: 200
# Successfully updated track info for batch 173700 to 173749
# Status code for batch: 200
# Successfully updated track info for batch 173750 to 173799
# Status code for batch: 200
# Successfully updated track info for batch 173800 to 173849
# Status code for batch: 200
# Successfully updated track info for batch 173850 to 173899
# Status code for batch: 200
# Successfully updated track info for batch 173900 to 173949
# Status code for batch: 200
# Successfully updated track info for batch 173950 to 173999
# Status code for batch: 200
# Successfully updated track info for batch 174000 to 174049
# Status code for batch: 200
# Successfully updated track info for batch 174050 to 174099
# Status code for batch: 200
# Successfully updated track info for batch 174100 to 174149
# Status code for batch: 200
# Successfully updated track info for batch 174150 to 174199
# Status code for batch: 200
# Successfully updated track info for batch 174200 to 174249
# Status code for batch: 200
# Successfully updated track info for batch 174250 to 174299
# Status code for batch: 200
# Successfully updated track info for batch 174300 to 174349
# Status code for batch: 200
# Successfully updated track info for batch 174350 to 174399
# Status code for batch: 200
# Successfully updated track info for batch 174400 to 174449
# Status code for batch: 200
# Successfully updated track info for batch 174450 to 174499
# Status code for batch: 200
# Successfully updated track info for batch 174500 to 174549
# Status code for batch: 200
# Successfully updated track info for batch 174550 to 174599
# Status code for batch: 200
# Successfully updated track info for batch 174600 to 174649
# Status code for batch: 200
# Successfully updated track info for batch 174650 to 174699
# Status code for batch: 200
# Successfully updated track info for batch 174700 to 174749
# Status code for batch: 200
# Successfully updated track info for batch 174750 to 174799
# Status code for batch: 200
# Successfully updated track info for batch 174800 to 174849
# Status code for batch: 200
# Successfully updated track info for batch 174850 to 174899
# Status code for batch: 200
# Successfully updated track info for batch 174900 to 174949
# Status code for batch: 200
# Successfully updated track info for batch 174950 to 174999
# Status code for batch: 200
# Successfully updated track info for batch 175000 to 175049
# Status code for batch: 200
# Successfully updated track info for batch 175050 to 175099
# Status code for batch: 200
# Successfully updated track info for batch 175100 to 175149
# Status code for batch: 200
# Successfully updated track info for batch 175150 to 175199
# Skipping None track data
# Status code for batch: 200
# Successfully updated track info for batch 175200 to 175249
# Status code for batch: 200
# Successfully updated track info for batch 175250 to 175299
# Status code for batch: 200
# Successfully updated track info for batch 175300 to 175349
# Status code for batch: 200
# Successfully updated track info for batch 175350 to 175399
# Status code for batch: 200
# Successfully updated track info for batch 175400 to 175449
# Status code for batch: 200
# Successfully updated track info for batch 175450 to 175499
# Status code for batch: 200
# Successfully updated track info for batch 175500 to 175549
# Status code for batch: 200
# Successfully updated track info for batch 175550 to 175599
# Status code for batch: 200
# Successfully updated track info for batch 175600 to 175649
# Status code for batch: 200
# Successfully updated track info for batch 175650 to 175699
# Status code for batch: 200
# Successfully updated track info for batch 175700 to 175749
# Status code for batch: 200
# Successfully updated track info for batch 175750 to 175799
# Status code for batch: 200
# Successfully updated track info for batch 175800 to 175849
# Status code for batch: 200
# Successfully updated track info for batch 175850 to 175899
# Status code for batch: 200
# Successfully updated track info for batch 175900 to 175949
# Status code for batch: 200
# Successfully updated track info for batch 175950 to 175999
# Status code for batch: 200
# Successfully updated track info for batch 176000 to 176049
# Status code for batch: 200
# Successfully updated track info for batch 176050 to 176099
# Status code for batch: 200
# Successfully updated track info for batch 176100 to 176149
# Status code for batch: 200
# Successfully updated track info for batch 176150 to 176199
# Status code for batch: 200
# Successfully updated track info for batch 176200 to 176249
# Status code for batch: 200
# Successfully updated track info for batch 176250 to 176299
# Status code for batch: 200
# Successfully updated track info for batch 176300 to 176349
# Status code for batch: 200
# Successfully updated track info for batch 176350 to 176399
# Status code for batch: 200
# Successfully updated track info for batch 176400 to 176449
# Status code for batch: 200
# Successfully updated track info for batch 176450 to 176499
# Status code for batch: 200
# Successfully updated track info for batch 176500 to 176549
# Status code for batch: 200
# Successfully updated track info for batch 176550 to 176599
# Status code for batch: 200
# Successfully updated track info for batch 176600 to 176649
# Status code for batch: 200
# Successfully updated track info for batch 176650 to 176699
# Status code for batch: 200
# Successfully updated track info for batch 176700 to 176749
# Status code for batch: 200
# Successfully updated track info for batch 176750 to 176799
# Status code for batch: 200
# Successfully updated track info for batch 176800 to 176849
# Status code for batch: 200
# Successfully updated track info for batch 176850 to 176899
# Status code for batch: 200
# Successfully updated track info for batch 176900 to 176949
# Status code for batch: 200
# Successfully updated track info for batch 176950 to 176999
# Status code for batch: 200
# Successfully updated track info for batch 177000 to 177049
# Status code for batch: 200
# Successfully updated track info for batch 177050 to 177099
# Status code for batch: 200
# Successfully updated track info for batch 177100 to 177149
# Status code for batch: 200
# Successfully updated track info for batch 177150 to 177199
# Status code for batch: 200
# Successfully updated track info for batch 177200 to 177249
# Status code for batch: 200
# Successfully updated track info for batch 177250 to 177299
# Status code for batch: 200
# Successfully updated track info for batch 177300 to 177349
# Status code for batch: 200
# Successfully updated track info for batch 177350 to 177399
# Status code for batch: 200
# Successfully updated track info for batch 177400 to 177449
# Status code for batch: 200
# Successfully updated track info for batch 177450 to 177499
# Status code for batch: 200
# Successfully updated track info for batch 177500 to 177549
# Status code for batch: 200
# Successfully updated track info for batch 177550 to 177599
# Status code for batch: 200
# Successfully updated track info for batch 177600 to 177649
# Status code for batch: 200
# Successfully updated track info for batch 177650 to 177699
# Status code for batch: 200
# Successfully updated track info for batch 177700 to 177749
# Status code for batch: 200
# Successfully updated track info for batch 177750 to 177799
# Status code for batch: 200
# Successfully updated track info for batch 177800 to 177849
# Status code for batch: 200
# Successfully updated track info for batch 177850 to 177899
# Status code for batch: 200
# Successfully updated track info for batch 177900 to 177949
# Status code for batch: 200
# Successfully updated track info for batch 177950 to 177999
# Status code for batch: 200
# Successfully updated track info for batch 178000 to 178049
# Status code for batch: 200
# Successfully updated track info for batch 178050 to 178099
# Status code for batch: 200
# Successfully updated track info for batch 178100 to 178149
# Status code for batch: 200
# Successfully updated track info for batch 178150 to 178199
# Status code for batch: 200
# Successfully updated track info for batch 178200 to 178249
# Status code for batch: 200
# Successfully updated track info for batch 178250 to 178299
# Status code for batch: 200
# Successfully updated track info for batch 178300 to 178349
# Status code for batch: 200
# Successfully updated track info for batch 178350 to 178399
# Status code for batch: 200
# Successfully updated track info for batch 178400 to 178449
# Status code for batch: 200
# Successfully updated track info for batch 178450 to 178499
# Status code for batch: 200
# Successfully updated track info for batch 178500 to 178549
# Status code for batch: 200
# Successfully updated track info for batch 178550 to 178599
# Status code for batch: 200
# Successfully updated track info for batch 178600 to 178649
# Status code for batch: 200
# Successfully updated track info for batch 178650 to 178699
# Status code for batch: 200
# Successfully updated track info for batch 178700 to 178749
# Status code for batch: 200
# Successfully updated track info for batch 178750 to 178799
# Status code for batch: 200
# Successfully updated track info for batch 178800 to 178849
# Status code for batch: 200
# Successfully updated track info for batch 178850 to 178899
# Status code for batch: 200
# Successfully updated track info for batch 178900 to 178949
# Status code for batch: 200
# Successfully updated track info for batch 178950 to 178999
# Status code for batch: 200
# Successfully updated track info for batch 179000 to 179049
# Status code for batch: 200
# Successfully updated track info for batch 179050 to 179099
# Status code for batch: 200
# Successfully updated track info for batch 179100 to 179149
# Status code for batch: 200
# Successfully updated track info for batch 179150 to 179199
# Status code for batch: 200
# Successfully updated track info for batch 179200 to 179249
# Status code for batch: 200
# Successfully updated track info for batch 179250 to 179299
# Status code for batch: 200
# Successfully updated track info for batch 179300 to 179349
# Status code for batch: 200
# Successfully updated track info for batch 179350 to 179399
# Status code for batch: 200
# Successfully updated track info for batch 179400 to 179449
# Status code for batch: 200
# Successfully updated track info for batch 179450 to 179499
# Status code for batch: 200
# Successfully updated track info for batch 179500 to 179549
# Status code for batch: 200
# Successfully updated track info for batch 179550 to 179599
# Status code for batch: 200
# Successfully updated track info for batch 179600 to 179649
# Status code for batch: 200
# Successfully updated track info for batch 179650 to 179699
# Status code for batch: 200
# Successfully updated track info for batch 179700 to 179749
# Status code for batch: 200
# Successfully updated track info for batch 179750 to 179799
# Status code for batch: 200
# Successfully updated track info for batch 179800 to 179849
# Status code for batch: 200
# Successfully updated track info for batch 179850 to 179899
# Status code for batch: 200
# Successfully updated track info for batch 179900 to 179949
# Status code for batch: 200
# Successfully updated track info for batch 179950 to 179999
# Status code for batch: 200
# Successfully updated track info for batch 180000 to 180049
# Status code for batch: 200
# Successfully updated track info for batch 180050 to 180099
# Status code for batch: 200
# Successfully updated track info for batch 180100 to 180149
# Status code for batch: 200
# Successfully updated track info for batch 180150 to 180199
# Status code for batch: 200
# Successfully updated track info for batch 180200 to 180249
# Status code for batch: 200
# Successfully updated track info for batch 180250 to 180299
# Status code for batch: 200
# Successfully updated track info for batch 180300 to 180349
# Status code for batch: 200
# Successfully updated track info for batch 180350 to 180399
# Status code for batch: 200
# Successfully updated track info for batch 180400 to 180449
# Status code for batch: 200
# Successfully updated track info for batch 180450 to 180499
# Status code for batch: 200
# Successfully updated track info for batch 180500 to 180549
# Status code for batch: 200
# Successfully updated track info for batch 180550 to 180599
# Status code for batch: 200
# Successfully updated track info for batch 180600 to 180649
# Status code for batch: 200
# Successfully updated track info for batch 180650 to 180699
# Status code for batch: 200
# Successfully updated track info for batch 180700 to 180749
# Status code for batch: 200
# Successfully updated track info for batch 180750 to 180799
# Status code for batch: 200
# Successfully updated track info for batch 180800 to 180849
# Status code for batch: 200
# Successfully updated track info for batch 180850 to 180899
# Status code for batch: 200
# Successfully updated track info for batch 180900 to 180949
# Status code for batch: 200
# Successfully updated track info for batch 180950 to 180999
# Status code for batch: 200
# Successfully updated track info for batch 181000 to 181049
# Status code for batch: 200
# Successfully updated track info for batch 181050 to 181099
# Status code for batch: 200
# Successfully updated track info for batch 181100 to 181149
# Status code for batch: 200
# Successfully updated track info for batch 181150 to 181199
# Status code for batch: 200
# Successfully updated track info for batch 181200 to 181249
# Status code for batch: 200
# Successfully updated track info for batch 181250 to 181299
# Status code for batch: 200
# Successfully updated track info for batch 181300 to 181349
# Status code for batch: 200
# Successfully updated track info for batch 181350 to 181399
# Status code for batch: 200
# Successfully updated track info for batch 181400 to 181449
# Status code for batch: 200
# Successfully updated track info for batch 181450 to 181499
# Status code for batch: 200
# Successfully updated track info for batch 181500 to 181549
# Status code for batch: 200
# Successfully updated track info for batch 181550 to 181599
# Status code for batch: 200
# Successfully updated track info for batch 181600 to 181649
# Status code for batch: 200
# Successfully updated track info for batch 181650 to 181699
# Status code for batch: 200
# Successfully updated track info for batch 181700 to 181749
# Status code for batch: 200
# Successfully updated track info for batch 181750 to 181799
# Status code for batch: 200
# Successfully updated track info for batch 181800 to 181849
# Status code for batch: 200
# Successfully updated track info for batch 181850 to 181899
# Status code for batch: 200
# Successfully updated track info for batch 181900 to 181949
# Status code for batch: 200
# Successfully updated track info for batch 181950 to 181999
# Status code for batch: 200
# Successfully updated track info for batch 182000 to 182049
# Status code for batch: 200
# Successfully updated track info for batch 182050 to 182099
# Status code for batch: 200
# Successfully updated track info for batch 182100 to 182149
# Status code for batch: 200
# Successfully updated track info for batch 182150 to 182199
# Status code for batch: 200
# Successfully updated track info for batch 182200 to 182249
# Status code for batch: 200
# Successfully updated track info for batch 182250 to 182299
# Rate limit exceeded. Retrying in 77253 seconds.

# %%
# path to database file
status, conn  = create_connection("playlist_analysis.db")

if status:
    df_tracks = pd.read_sql_query("SELECT * FROM tracks;", conn)
else:
    print("Failed to establish a connection.")

missing = df_tracks.isnull().sum()
print(missing)
# Out:
# Connected to database
# t_uri                 0
# t_name                0
# t_duration_ms         0
# artist_uri            0
# album_uri             0
# popularity           38
# explicit             38
# preview_url      153627
# last_updated     297900
# dtype: int64

# %%
# Convert 't_duration_ms' to seconds
df_tracks['t_duration_sec'] = df_tracks['t_duration_ms'] / 1000
df_tracks.describe()
# Out:
#        t_duration_ms     popularity       explicit  t_duration_sec
# count   3.015460e+05  301508.000000  301508.000000   301546.000000
# mean    2.407204e+05      16.803740       0.122222      240.720411
# std     1.108625e+05      18.574412       0.327543      110.862513
# min     0.000000e+00       0.000000       0.000000        0.000000
# 25%     1.915180e+05       0.000000       0.000000      191.518000
# 50%     2.256530e+05      11.000000       0.000000      225.653000
# 75%     2.694530e+05      31.000000       0.000000      269.453000
# max     6.348017e+06      91.000000       1.000000     6348.017000
