# %% [markdown]
# # Artist Exploration

# %% [markdown]
# ## Imports

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
# Load the 'artists' table into a DataFrame
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file"""
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print("Connected to database")
        return True, conn
    except sqlite3.Error as e:
        print(f"Failed to connect: {e}")
        return False, None

# path to database file
status, conn  = create_connection("/Users/fried/Documents/DataScience/4season/DSP/Spotify/DSP_project/playlist_analysis.db")

if status:
    df_artists = pd.read_sql_query("SELECT * FROM artists;", conn)
else:
    print("Failed to establish a connection.")

# Display first few rows of the DataFrame to get an overview
df_artists.head()
# Out:
# Connected to database
#                               artist_uri        artist_name  popularity  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk      Missy Elliott        74.0
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4     Britney Spears        82.0
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m            Beyoncé        88.0
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7  Justin Timberlake        81.0
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij             Shaggy        75.0
#
#     followers                                             genres
# 0   2180138.0  dance pop, hip hop, hip pop, pop rap, r&b, rap...
# 1  12071720.0                                     dance pop, pop
# 2  34051083.0                                dance pop, pop, r&b
# 3  12752558.0                                     dance pop, pop
# 4   1909526.0                  dance pop, pop rap, reggae fusion

# %% [markdown]
# ## Fill missing values

# %% [markdown]
# ### Fetch data from Spotify API

# %%
missing = df_artists.isnull().sum()
print(missing)
# Out:
# artist_uri       0
# artist_name      0
# popularity     563
# followers      563
# genres         563
# dtype: int64

# %%
import requests
import time
import sqlite3
import json

# Connect to the database
def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except sqlite3.Error as e:
        print(e)
        return None

# Get all artist URIs from the database
def get_all_artist_uris(conn):
    cur = conn.cursor()
    cur.execute("SELECT artist_uri FROM artists WHERE popularity IS NULL OR followers IS NULL OR genres IS NULL;")
    return cur.fetchall()

# Create Spotify access token
def get_spotify_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_response = requests.post(auth_url, {
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
    })
    auth_response_data = auth_response.json()
    return auth_response_data['access_token'], auth_response_data['expires_in']

# Check if the token is about to expire
def is_token_expired(token_time, expires_in):
    current_time = time.time()
    return current_time - token_time >= expires_in - 10  # 10 seconds buffer

# Alter the artists table
def alter_artists_table(conn):
    try:
        cur = conn.cursor()
        cur.execute(f"ALTER TABLE artists ADD COLUMN last_updated TEXT;")
        conn.commit()
        print(f"Artists table altered successfully. Added column UPDATED.")
    except sqlite3.Error as e:
        print(f"SQL error: {e}")
# Update artist information using batch requests
def update_artists_info_batch(conn, artist_uris, access_token):
    headers = {'Authorization': f'Bearer {access_token}'}
    artist_ids = ','.join([uri.split(":")[-1] for uri in artist_uris])  # Extract the artist IDs from the URIs
    r = requests.get(f"https://api.spotify.com/v1/artists?ids={artist_ids}", headers=headers)

    # Handle rate limiting
    if r.status_code == 429:
        retry_after = int(r.headers.get('Retry-After', 60))
        print(f"Rate limit exceeded. Retrying in {retry_after} seconds.")
        time.sleep(retry_after)
        update_artists_info_batch(conn, artist_uris, access_token)  # Recursive retry
        return

    elif r.status_code != 200:
        print(f"Batch Request Error: Code: {r.status_code} : {r.text}")
        return

    else:
        artists_data = r.json()['artists']
        cur = conn.cursor()
        for artist_data in artists_data:
            popularity = artist_data.get('popularity', None)
            followers = artist_data.get('followers', {}).get('total', None)
            genres = ', '.join(artist_data.get('genres', []))
            artist_uri = f"spotify:artist:{artist_data['id']}"
            
            cur.execute("UPDATE artists SET popularity = ?, followers = ?, genres = ? WHERE artist_uri = ?;",
                        (popularity, followers, genres, artist_uri))
            conn.commit()
            print(f"Updating artist: {artist_uri}")
            print(f"Data received from API: {artist_data}")


# Main function
if __name__ == '__main__':
    # Initialize
    conn = create_connection('playlist_analysis.db')
    client_id = '954461108b34465b8c6e33d9f2b20f95'
    client_secret = '80bf594500674a0396c45f57a779c43d'
    access_token, expires_in = get_spotify_access_token(client_id, client_secret)
    token_time = time.time()  # Store the current time
    
    # Get all artist URIs
    all_artist_uris = get_all_artist_uris(conn)
    total_artists = len(all_artist_uris)

    # Initialize rate limiting variables
    rate_limit_window = 25  # seconds
    max_requests = 20  # Maximum number of requests in rate_limit_window
    request_times = []

    # Update artists in batches
    for i in range(0, len(all_artist_uris), 50):
        batch = all_artist_uris[i:i+50]
        
        # Check if the token is about to expire
        if is_token_expired(token_time, expires_in):
            print("Refreshing token...")
            access_token, expires_in = get_spotify_access_token(client_id, client_secret)
            token_time = time.time()

        # Check rate limit
        current_time = time.time()
        request_times = [t for t in request_times if current_time - t < rate_limit_window]
        if len(request_times) >= max_requests:
            sleep_time = rate_limit_window - (current_time - min(request_times))
            print(f"Rate limit reached. Sleeping for {sleep_time:.2f} seconds.")
            time.sleep(sleep_time)
        
        update_artists_info_batch(conn, [uri for uri, in batch], access_token)
        request_times.append(time.time())
        
        if (i + len(batch)) % 10 == 0:
            print(f"Processed {i + len(batch)} of {total_artists} artists.")

    conn.close()
# Out:
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:6udveWUgX4vu75FF0DTrXV
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6udveWUgX4vu75FF0DTrXV'}, 'followers': {'href': None, 'total': 1263606}, 'genres': ['k-pop', 'korean r&b'], 'href': 'https://api.spotify.com/v1/artists/6udveWUgX4vu75FF0DTrXV', 'id': '6udveWUgX4vu75FF0DTrXV', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb496189630cd3cb0c7b593fee', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174496189630cd3cb0c7b593fee', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178496189630cd3cb0c7b593fee', 'width': 160}], 'name': 'TAEYANG', 'popularity': 66, 'type': 'artist', 'uri': 'spotify:artist:6udveWUgX4vu75FF0DTrXV'}
# Updating artist: spotify:artist:0uCCBpmg6MrPb1KY2msceF
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0uCCBpmg6MrPb1KY2msceF'}, 'followers': {'href': None, 'total': 427315}, 'genres': ['classic dubstep', 'electronica', 'future garage', 'hauntology', 'intelligent dance music', 'trip hop', 'uk bass', 'wonky'], 'href': 'https://api.spotify.com/v1/artists/0uCCBpmg6MrPb1KY2msceF', 'id': '0uCCBpmg6MrPb1KY2msceF', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb4be7334b7aed9ca32a732aeb', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051744be7334b7aed9ca32a732aeb', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1784be7334b7aed9ca32a732aeb', 'width': 160}], 'name': 'Burial', 'popularity': 49, 'type': 'artist', 'uri': 'spotify:artist:0uCCBpmg6MrPb1KY2msceF'}
# Updating artist: spotify:artist:5cM1PvItlR21WUyBnsdMcn
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5cM1PvItlR21WUyBnsdMcn'}, 'followers': {'href': None, 'total': 418008}, 'genres': ['contemporary jazz', 'indie jazz', 'indie soul', 'jazz', 'modern jazz piano', 'neo r&b', 'neo soul'], 'href': 'https://api.spotify.com/v1/artists/5cM1PvItlR21WUyBnsdMcn', 'id': '5cM1PvItlR21WUyBnsdMcn', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebeac91c1b242fe7aff48894f5', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174eac91c1b242fe7aff48894f5', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178eac91c1b242fe7aff48894f5', 'width': 160}], 'name': 'Robert Glasper', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:5cM1PvItlR21WUyBnsdMcn'}
# Updating artist: spotify:artist:32aFdXARUiqP81SXqIPD4w
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/32aFdXARUiqP81SXqIPD4w'}, 'followers': {'href': None, 'total': 164239}, 'genres': ['folk-pop'], 'href': 'https://api.spotify.com/v1/artists/32aFdXARUiqP81SXqIPD4w', 'id': '32aFdXARUiqP81SXqIPD4w', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb6898fb91c70d5e6a10a67fde', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051746898fb91c70d5e6a10a67fde', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1786898fb91c70d5e6a10a67fde', 'width': 160}], 'name': 'Yael Naim', 'popularity': 49, 'type': 'artist', 'uri': 'spotify:artist:32aFdXARUiqP81SXqIPD4w'}
# Updating artist: spotify:artist:0RkqytrwoGyXGvDiZwT6i2
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0RkqytrwoGyXGvDiZwT6i2'}, 'followers': {'href': None, 'total': 33402}, 'genres': ['soundtrack'], 'href': 'https://api.spotify.com/v1/artists/0RkqytrwoGyXGvDiZwT6i2', 'id': '0RkqytrwoGyXGvDiZwT6i2', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb8f9c3f0a123aecf196868c9c', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051748f9c3f0a123aecf196868c9c', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1788f9c3f0a123aecf196868c9c', 'width': 160}], 'name': 'Michael Andrews', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:0RkqytrwoGyXGvDiZwT6i2'}
# Updating artist: spotify:artist:3XcCT5MPlQPWFTJyzXbfuX
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XcCT5MPlQPWFTJyzXbfuX'}, 'followers': {'href': None, 'total': 98681}, 'genres': ['detroit hip hop', 'pop r&b'], 'href': 'https://api.spotify.com/v1/artists/3XcCT5MPlQPWFTJyzXbfuX', 'id': '3XcCT5MPlQPWFTJyzXbfuX', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebea7af9887c128b62c4a304d8', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174ea7af9887c128b62c4a304d8', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178ea7af9887c128b62c4a304d8', 'width': 160}], 'name': 'Maejor', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:3XcCT5MPlQPWFTJyzXbfuX'}
# Updating artist: spotify:artist:6eIPFXnKPqSQVxgsU4hELI
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6eIPFXnKPqSQVxgsU4hELI'}, 'followers': {'href': None, 'total': 234396}, 'genres': ['idol', 'post-teen pop'], 'href': 'https://api.spotify.com/v1/artists/6eIPFXnKPqSQVxgsU4hELI', 'id': '6eIPFXnKPqSQVxgsU4hELI', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb768b0d04e56d4f126ac4feb1', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174768b0d04e56d4f126ac4feb1', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178768b0d04e56d4f126ac4feb1', 'width': 160}], 'name': 'Nick Carter', 'popularity': 37, 'type': 'artist', 'uri': 'spotify:artist:6eIPFXnKPqSQVxgsU4hELI'}
# Updating artist: spotify:artist:01nUdqwuIHCHLZNP2TvYVF
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/01nUdqwuIHCHLZNP2TvYVF'}, 'followers': {'href': None, 'total': 62184}, 'genres': ['reggaeton flow'], 'href': 'https://api.spotify.com/v1/artists/01nUdqwuIHCHLZNP2TvYVF', 'id': '01nUdqwuIHCHLZNP2TvYVF', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb5e337b038f5cccbf070becba', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051745e337b038f5cccbf070becba', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1785e337b038f5cccbf070becba', 'width': 160}], 'name': 'Boy Wonder CF', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:01nUdqwuIHCHLZNP2TvYVF'}
# Updating artist: spotify:artist:6N4VOBE2wNnRIINe3922Oc
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6N4VOBE2wNnRIINe3922Oc'}, 'followers': {'href': None, 'total': 400960}, 'genres': ['banda', 'duranguense', 'musica mexicana', 'norteno'], 'href': 'https://api.spotify.com/v1/artists/6N4VOBE2wNnRIINe3922Oc', 'id': '6N4VOBE2wNnRIINe3922Oc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebd30a2a8da7a9799569e064c2', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174d30a2a8da7a9799569e064c2', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178d30a2a8da7a9799569e064c2', 'width': 160}], 'name': 'Los Primos MX', 'popularity': 61, 'type': 'artist', 'uri': 'spotify:artist:6N4VOBE2wNnRIINe3922Oc'}
# Updating artist: spotify:artist:5g1lWbZIQ0LCWbKmRJDSSn
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5g1lWbZIQ0LCWbKmRJDSSn'}, 'followers': {'href': None, 'total': 78363}, 'genres': ['gospel'], 'href': 'https://api.spotify.com/v1/artists/5g1lWbZIQ0LCWbKmRJDSSn', 'id': '5g1lWbZIQ0LCWbKmRJDSSn', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732a81419511dd80778cf368aa', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022a81419511dd80778cf368aa', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512a81419511dd80778cf368aa', 'width': 64}], 'name': 'James Cleveland', 'popularity': 32, 'type': 'artist', 'uri': 'spotify:artist:5g1lWbZIQ0LCWbKmRJDSSn'}
# Updating artist: spotify:artist:0o0rlxlC3ApLWsxFkUjMXc
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0o0rlxlC3ApLWsxFkUjMXc'}, 'followers': {'href': None, 'total': 1203250}, 'genres': ['reggae', 'roots reggae'], 'href': 'https://api.spotify.com/v1/artists/0o0rlxlC3ApLWsxFkUjMXc', 'id': '0o0rlxlC3ApLWsxFkUjMXc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb2ff8a94ee073f8024665826b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051742ff8a94ee073f8024665826b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1782ff8a94ee073f8024665826b', 'width': 160}], 'name': 'Ziggy Marley', 'popularity': 55, 'type': 'artist', 'uri': 'spotify:artist:0o0rlxlC3ApLWsxFkUjMXc'}
# Updating artist: spotify:artist:6RGxLsQUoGk5PLyMVwb3yE
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RGxLsQUoGk5PLyMVwb3yE'}, 'followers': {'href': None, 'total': 451019}, 'genres': ['new romantic', 'new wave pop'], 'href': 'https://api.spotify.com/v1/artists/6RGxLsQUoGk5PLyMVwb3yE', 'id': '6RGxLsQUoGk5PLyMVwb3yE', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb5b3e839d57fb4b453a171076', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051745b3e839d57fb4b453a171076', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1785b3e839d57fb4b453a171076', 'width': 160}], 'name': 'Sananda Maitreya', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:6RGxLsQUoGk5PLyMVwb3yE'}
# Updating artist: spotify:artist:6uGKydhYXrVOEXM6QbVzyH
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6uGKydhYXrVOEXM6QbVzyH'}, 'followers': {'href': None, 'total': 12799}, 'genres': ['dutch pop', 'vocal house'], 'href': 'https://api.spotify.com/v1/artists/6uGKydhYXrVOEXM6QbVzyH', 'id': '6uGKydhYXrVOEXM6QbVzyH', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb9521fb411160e4589df0a67b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051749521fb411160e4589df0a67b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1789521fb411160e4589df0a67b', 'width': 160}], 'name': 'Amber', 'popularity': 43, 'type': 'artist', 'uri': 'spotify:artist:6uGKydhYXrVOEXM6QbVzyH'}
# Updating artist: spotify:artist:0CiLVKp7LJTm0c8jdUmQNy
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0CiLVKp7LJTm0c8jdUmQNy'}, 'followers': {'href': None, 'total': 25883}, 'genres': ['dancehall', 'french hip hop', 'riddim'], 'href': 'https://api.spotify.com/v1/artists/0CiLVKp7LJTm0c8jdUmQNy', 'id': '0CiLVKp7LJTm0c8jdUmQNy', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba5137c3502ce027b618a15f9', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a5137c3502ce027b618a15f9', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a5137c3502ce027b618a15f9', 'width': 160}], 'name': 'Agent Sasco (Assassin)', 'popularity': 41, 'type': 'artist', 'uri': 'spotify:artist:0CiLVKp7LJTm0c8jdUmQNy'}
# Updating artist: spotify:artist:1UHB4MqbKSnwtMoArh4GUp
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1UHB4MqbKSnwtMoArh4GUp'}, 'followers': {'href': None, 'total': 8793}, 'genres': ['soul blues', 'southern soul', 'southern soul blues'], 'href': 'https://api.spotify.com/v1/artists/1UHB4MqbKSnwtMoArh4GUp', 'id': '1UHB4MqbKSnwtMoArh4GUp', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273a900ad1a1ba3f8d172f57624', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02a900ad1a1ba3f8d172f57624', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851a900ad1a1ba3f8d172f57624', 'width': 64}], 'name': 'Lee "Shot" Williams', 'popularity': 16, 'type': 'artist', 'uri': 'spotify:artist:1UHB4MqbKSnwtMoArh4GUp'}
# Updating artist: spotify:artist:0GzIauSfKRc5BlNXpTWAGz
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GzIauSfKRc5BlNXpTWAGz'}, 'followers': {'href': None, 'total': 171606}, 'genres': ['contemporary country'], 'href': 'https://api.spotify.com/v1/artists/0GzIauSfKRc5BlNXpTWAGz', 'id': '0GzIauSfKRc5BlNXpTWAGz', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebc245cc4471104cfd0133ce4e', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174c245cc4471104cfd0133ce4e', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178c245cc4471104cfd0133ce4e', 'width': 160}], 'name': 'Jessie James Decker', 'popularity': 44, 'type': 'artist', 'uri': 'spotify:artist:0GzIauSfKRc5BlNXpTWAGz'}
# Updating artist: spotify:artist:1IGGfstLsypGtdI55tT3Z1
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1IGGfstLsypGtdI55tT3Z1'}, 'followers': {'href': None, 'total': 56581}, 'genres': ['anthem worship', 'ccm', 'worship'], 'href': 'https://api.spotify.com/v1/artists/1IGGfstLsypGtdI55tT3Z1', 'id': '1IGGfstLsypGtdI55tT3Z1', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebc0175bcdd2360478cd342e1b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174c0175bcdd2360478cd342e1b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178c0175bcdd2360478cd342e1b', 'width': 160}], 'name': 'North Point Worship', 'popularity': 48, 'type': 'artist', 'uri': 'spotify:artist:1IGGfstLsypGtdI55tT3Z1'}
# Updating artist: spotify:artist:3XcCT5MPlQPWFTJyzXbfuX
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XcCT5MPlQPWFTJyzXbfuX'}, 'followers': {'href': None, 'total': 98681}, 'genres': ['detroit hip hop', 'pop r&b'], 'href': 'https://api.spotify.com/v1/artists/3XcCT5MPlQPWFTJyzXbfuX', 'id': '3XcCT5MPlQPWFTJyzXbfuX', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebea7af9887c128b62c4a304d8', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174ea7af9887c128b62c4a304d8', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178ea7af9887c128b62c4a304d8', 'width': 160}], 'name': 'Maejor', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:3XcCT5MPlQPWFTJyzXbfuX'}
# Updating artist: spotify:artist:4QU2KMv8a76IHXUYruc3r2
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/4QU2KMv8a76IHXUYruc3r2'}, 'followers': {'href': None, 'total': 103987}, 'genres': ['ccm', 'deep ccm', 'world worship', 'worship'], 'href': 'https://api.spotify.com/v1/artists/4QU2KMv8a76IHXUYruc3r2', 'id': '4QU2KMv8a76IHXUYruc3r2', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb9c9a3513fd9087e32f7d60ec', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051749c9a3513fd9087e32f7d60ec', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1789c9a3513fd9087e32f7d60ec', 'width': 160}], 'name': 'Citipointe Worship', 'popularity': 42, 'type': 'artist', 'uri': 'spotify:artist:4QU2KMv8a76IHXUYruc3r2'}
# Updating artist: spotify:artist:1ackd5XprZEkH3McKbQD51
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ackd5XprZEkH3McKbQD51'}, 'followers': {'href': None, 'total': 1785677}, 'genres': ['electro latino', 'spanish pop'], 'href': 'https://api.spotify.com/v1/artists/1ackd5XprZEkH3McKbQD51', 'id': '1ackd5XprZEkH3McKbQD51', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb9bff446a54ba1ca20ddbb001', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051749bff446a54ba1ca20ddbb001', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1789bff446a54ba1ca20ddbb001', 'width': 160}], 'name': 'Juan Magán', 'popularity': 67, 'type': 'artist', 'uri': 'spotify:artist:1ackd5XprZEkH3McKbQD51'}
# Updating artist: spotify:artist:24sVPKlhUfQ8rMyUg7qLUq
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/24sVPKlhUfQ8rMyUg7qLUq'}, 'followers': {'href': None, 'total': 102354}, 'genres': ['filthstep'], 'href': 'https://api.spotify.com/v1/artists/24sVPKlhUfQ8rMyUg7qLUq', 'id': '24sVPKlhUfQ8rMyUg7qLUq', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb0a9c30689358ef0be89d00f7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051740a9c30689358ef0be89d00f7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1780a9c30689358ef0be89d00f7', 'width': 160}], 'name': 'RAIZHELL', 'popularity': 59, 'type': 'artist', 'uri': 'spotify:artist:24sVPKlhUfQ8rMyUg7qLUq'}
# Updating artist: spotify:artist:1VpKMEWBe1h0nsFZ2xrC5r
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1VpKMEWBe1h0nsFZ2xrC5r'}, 'followers': {'href': None, 'total': 0}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/1VpKMEWBe1h0nsFZ2xrC5r', 'id': '1VpKMEWBe1h0nsFZ2xrC5r', 'images': [], 'name': 'Pegboard Nerds & Tristam', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:1VpKMEWBe1h0nsFZ2xrC5r'}
# Updating artist: spotify:artist:78sJswwVn4P8aEhkF4K6fQ
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/78sJswwVn4P8aEhkF4K6fQ'}, 'followers': {'href': None, 'total': 812773}, 'genres': ['k-pop', 'korean r&b'], 'href': 'https://api.spotify.com/v1/artists/78sJswwVn4P8aEhkF4K6fQ', 'id': '78sJswwVn4P8aEhkF4K6fQ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb56eabce4db8b2827505eba14', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517456eabce4db8b2827505eba14', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17856eabce4db8b2827505eba14', 'width': 160}], 'name': 'HYOLYN', 'popularity': 52, 'type': 'artist', 'uri': 'spotify:artist:78sJswwVn4P8aEhkF4K6fQ'}
# Updating artist: spotify:artist:7n2odaCKgBSfDLKlSDJ8Fs
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2odaCKgBSfDLKlSDJ8Fs'}, 'followers': {'href': None, 'total': 45}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/7n2odaCKgBSfDLKlSDJ8Fs', 'id': '7n2odaCKgBSfDLKlSDJ8Fs', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2738dce1c284fe4e851be3c4226', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e028dce1c284fe4e851be3c4226', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048518dce1c284fe4e851be3c4226', 'width': 64}], 'name': 'All That', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:7n2odaCKgBSfDLKlSDJ8Fs'}
# Updating artist: spotify:artist:1G1mX30GpUJqOr1QU2eBSs
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1G1mX30GpUJqOr1QU2eBSs'}, 'followers': {'href': None, 'total': 660562}, 'genres': ['new romantic', 'new wave', 'new wave pop', 'synthpop'], 'href': 'https://api.spotify.com/v1/artists/1G1mX30GpUJqOr1QU2eBSs', 'id': '1G1mX30GpUJqOr1QU2eBSs', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebc948e0ba1e0c16f8c8ab6ad6', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174c948e0ba1e0c16f8c8ab6ad6', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178c948e0ba1e0c16f8c8ab6ad6', 'width': 160}], 'name': 'Yazoo', 'popularity': 57, 'type': 'artist', 'uri': 'spotify:artist:1G1mX30GpUJqOr1QU2eBSs'}
# Updating artist: spotify:artist:2UCzkuXiE37VD7K123J4Tf
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/2UCzkuXiE37VD7K123J4Tf'}, 'followers': {'href': None, 'total': 18514}, 'genres': ['rajasthani folk', 'sufi', 'world fusion'], 'href': 'https://api.spotify.com/v1/artists/2UCzkuXiE37VD7K123J4Tf', 'id': '2UCzkuXiE37VD7K123J4Tf', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebcc04e29afb13c5f474a2bd0a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174cc04e29afb13c5f474a2bd0a', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178cc04e29afb13c5f474a2bd0a', 'width': 160}], 'name': 'Shye Ben Tzur', 'popularity': 29, 'type': 'artist', 'uri': 'spotify:artist:2UCzkuXiE37VD7K123J4Tf'}
# Updating artist: spotify:artist:5Pb27ujIyYb33zBqVysBkj
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pb27ujIyYb33zBqVysBkj'}, 'followers': {'href': None, 'total': 1433475}, 'genres': ['australian electropop', 'indietronica'], 'href': 'https://api.spotify.com/v1/artists/5Pb27ujIyYb33zBqVysBkj', 'id': '5Pb27ujIyYb33zBqVysBkj', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba5d83556275bb22511f57624', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a5d83556275bb22511f57624', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a5d83556275bb22511f57624', 'width': 160}], 'name': 'RÜFÜS DU SOL', 'popularity': 70, 'type': 'artist', 'uri': 'spotify:artist:5Pb27ujIyYb33zBqVysBkj'}
# Updating artist: spotify:artist:0lf6aJ031s7V2V7eKB1mhz
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lf6aJ031s7V2V7eKB1mhz'}, 'followers': {'href': None, 'total': 489963}, 'genres': ['banda', 'musica mexicana', 'norteno'], 'href': 'https://api.spotify.com/v1/artists/0lf6aJ031s7V2V7eKB1mhz', 'id': '0lf6aJ031s7V2V7eKB1mhz', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb14745c545be8c605cfb5b520', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517414745c545be8c605cfb5b520', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17814745c545be8c605cfb5b520', 'width': 160}], 'name': 'Claudio Alcaraz', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:0lf6aJ031s7V2V7eKB1mhz'}
# Updating artist: spotify:artist:6xyaria4AcxjRuJZLkWvMW
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xyaria4AcxjRuJZLkWvMW'}, 'followers': {'href': None, 'total': 282594}, 'genres': ['boston hip hop', 'east coast hip hop', 'jazz rap'], 'href': 'https://api.spotify.com/v1/artists/6xyaria4AcxjRuJZLkWvMW', 'id': '6xyaria4AcxjRuJZLkWvMW', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba52ca5ab39f130ff72647ebb', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a52ca5ab39f130ff72647ebb', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a52ca5ab39f130ff72647ebb', 'width': 160}], 'name': 'Guru', 'popularity': 51, 'type': 'artist', 'uri': 'spotify:artist:6xyaria4AcxjRuJZLkWvMW'}
# Updating artist: spotify:artist:1YhMWppPt9RVODKD1KCs7W
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1YhMWppPt9RVODKD1KCs7W'}, 'followers': {'href': None, 'total': 2341342}, 'genres': ['banda', 'mariachi', 'musica mexicana', 'norteno', 'ranchera'], 'href': 'https://api.spotify.com/v1/artists/1YhMWppPt9RVODKD1KCs7W', 'id': '1YhMWppPt9RVODKD1KCs7W', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb644c62612088a5b31e08a692', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174644c62612088a5b31e08a692', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178644c62612088a5b31e08a692', 'width': 160}], 'name': 'El Bebeto', 'popularity': 62, 'type': 'artist', 'uri': 'spotify:artist:1YhMWppPt9RVODKD1KCs7W'}
# Updating artist: spotify:artist:27w1NoOLMX7tJMYqcetPyG
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/27w1NoOLMX7tJMYqcetPyG'}, 'followers': {'href': None, 'total': 617126}, 'genres': ['canadian hip hop', 'chicago rap', 'conscious hip hop', 'underground hip hop'], 'href': 'https://api.spotify.com/v1/artists/27w1NoOLMX7tJMYqcetPyG', 'id': '27w1NoOLMX7tJMYqcetPyG', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb409703a456d7a4401f307956', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174409703a456d7a4401f307956', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178409703a456d7a4401f307956', 'width': 160}], 'name': 'VIC MENSA', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:27w1NoOLMX7tJMYqcetPyG'}
# Updating artist: spotify:artist:6Z7JSzWmroQi34J1yz833c
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Z7JSzWmroQi34J1yz833c'}, 'followers': {'href': None, 'total': 34388}, 'genres': ['pinoy indie', 'pinoy r&b', 'pinoy trap'], 'href': 'https://api.spotify.com/v1/artists/6Z7JSzWmroQi34J1yz833c', 'id': '6Z7JSzWmroQi34J1yz833c', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb025382744b1a6d510795a943', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174025382744b1a6d510795a943', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178025382744b1a6d510795a943', 'width': 160}], 'name': 'crwn', 'popularity': 27, 'type': 'artist', 'uri': 'spotify:artist:6Z7JSzWmroQi34J1yz833c'}
# Updating artist: spotify:artist:5bWUlnPx9OYKsLiUJrhCA1
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5bWUlnPx9OYKsLiUJrhCA1'}, 'followers': {'href': None, 'total': 5974435}, 'genres': ['reggaeton', 'trap latino', 'urbano latino'], 'href': 'https://api.spotify.com/v1/artists/5bWUlnPx9OYKsLiUJrhCA1', 'id': '5bWUlnPx9OYKsLiUJrhCA1', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebbd83f498511bfb4f86711c1d', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174bd83f498511bfb4f86711c1d', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178bd83f498511bfb4f86711c1d', 'width': 160}], 'name': 'Jon Z', 'popularity': 70, 'type': 'artist', 'uri': 'spotify:artist:5bWUlnPx9OYKsLiUJrhCA1'}
# Updating artist: spotify:artist:1YcprGtF13BYCZQK9jYPEw
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1YcprGtF13BYCZQK9jYPEw'}, 'followers': {'href': None, 'total': 207503}, 'genres': ['alternative r&b', 'crank wave', 'lgbtq+ hip hop', 'slam poetry'], 'href': 'https://api.spotify.com/v1/artists/1YcprGtF13BYCZQK9jYPEw', 'id': '1YcprGtF13BYCZQK9jYPEw', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebf410bdbe8b63d3447e47dd56', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174f410bdbe8b63d3447e47dd56', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178f410bdbe8b63d3447e47dd56', 'width': 160}], 'name': 'Kae Tempest', 'popularity': 42, 'type': 'artist', 'uri': 'spotify:artist:1YcprGtF13BYCZQK9jYPEw'}
# Updating artist: spotify:artist:2UoLlLFDkqewHH7EzaZcl7
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/2UoLlLFDkqewHH7EzaZcl7'}, 'followers': {'href': None, 'total': 280701}, 'genres': ['salsa', 'salsa puertorriquena'], 'href': 'https://api.spotify.com/v1/artists/2UoLlLFDkqewHH7EzaZcl7', 'id': '2UoLlLFDkqewHH7EzaZcl7', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb1f64c5b3227ac65010ecb981', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051741f64c5b3227ac65010ecb981', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1781f64c5b3227ac65010ecb981', 'width': 160}], 'name': 'Luisito Ayala Y La Puerto Rican Power', 'popularity': 55, 'type': 'artist', 'uri': 'spotify:artist:2UoLlLFDkqewHH7EzaZcl7'}
# Updating artist: spotify:artist:3sUpZrkehiGBaMzs2h9Mmc
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3sUpZrkehiGBaMzs2h9Mmc'}, 'followers': {'href': None, 'total': 95080}, 'genres': ['modern country pop', 'texas country'], 'href': 'https://api.spotify.com/v1/artists/3sUpZrkehiGBaMzs2h9Mmc', 'id': '3sUpZrkehiGBaMzs2h9Mmc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb61ef1bed3253b222aeffa698', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517461ef1bed3253b222aeffa698', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17861ef1bed3253b222aeffa698', 'width': 160}], 'name': 'Corey Kent', 'popularity': 64, 'type': 'artist', 'uri': 'spotify:artist:3sUpZrkehiGBaMzs2h9Mmc'}
# Updating artist: spotify:artist:0c2Jcp6eQW5gsaPdrsI6uP
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0c2Jcp6eQW5gsaPdrsI6uP'}, 'followers': {'href': None, 'total': 16854}, 'genres': ['jewish pop'], 'href': 'https://api.spotify.com/v1/artists/0c2Jcp6eQW5gsaPdrsI6uP', 'id': '0c2Jcp6eQW5gsaPdrsI6uP', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb4fe95ac0066e023f1c606880', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051744fe95ac0066e023f1c606880', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1784fe95ac0066e023f1c606880', 'width': 160}], 'name': 'Ari Goldwag', 'popularity': 27, 'type': 'artist', 'uri': 'spotify:artist:0c2Jcp6eQW5gsaPdrsI6uP'}
# Updating artist: spotify:artist:0zQ5PXV7sxw2LAwMJusZog
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0zQ5PXV7sxw2LAwMJusZog'}, 'followers': {'href': None, 'total': 7980}, 'genres': ['jewish pop'], 'href': 'https://api.spotify.com/v1/artists/0zQ5PXV7sxw2LAwMJusZog', 'id': '0zQ5PXV7sxw2LAwMJusZog', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eba1c03f7b82f97f1a7107a2d9', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174a1c03f7b82f97f1a7107a2d9', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178a1c03f7b82f97f1a7107a2d9', 'width': 160}], 'name': 'Micha Gamerman', 'popularity': 21, 'type': 'artist', 'uri': 'spotify:artist:0zQ5PXV7sxw2LAwMJusZog'}
# Updating artist: spotify:artist:2X2cDFal9ci8yS5FDHYZv2
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/2X2cDFal9ci8yS5FDHYZv2'}, 'followers': {'href': None, 'total': 14070}, 'genres': ['future garage', 'portland hip hop'], 'href': 'https://api.spotify.com/v1/artists/2X2cDFal9ci8yS5FDHYZv2', 'id': '2X2cDFal9ci8yS5FDHYZv2', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebb494bac27e9546b45560cace', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174b494bac27e9546b45560cace', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178b494bac27e9546b45560cace', 'width': 160}], 'name': 'Karma Kid', 'popularity': 27, 'type': 'artist', 'uri': 'spotify:artist:2X2cDFal9ci8yS5FDHYZv2'}
# Updating artist: spotify:artist:2G8UkPZnQ8i78L8TfqP1X6
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/2G8UkPZnQ8i78L8TfqP1X6'}, 'followers': {'href': None, 'total': 366931}, 'genres': ['indie pop', 'pov: indie'], 'href': 'https://api.spotify.com/v1/artists/2G8UkPZnQ8i78L8TfqP1X6', 'id': '2G8UkPZnQ8i78L8TfqP1X6', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb12718bf9bb0a75f80d65895f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517412718bf9bb0a75f80d65895f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17812718bf9bb0a75f80d65895f', 'width': 160}], 'name': 'Christian Leave', 'popularity': 53, 'type': 'artist', 'uri': 'spotify:artist:2G8UkPZnQ8i78L8TfqP1X6'}
# Updating artist: spotify:artist:0HqBFsCRKEdhNRfh5e3sFD
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0HqBFsCRKEdhNRfh5e3sFD'}, 'followers': {'href': None, 'total': 1636}, 'genres': ['seattle indie'], 'href': 'https://api.spotify.com/v1/artists/0HqBFsCRKEdhNRfh5e3sFD', 'id': '0HqBFsCRKEdhNRfh5e3sFD', 'images': [{'height': 550, 'url': 'https://i.scdn.co/image/f10ff4b67a9801a7e575ca2c89fcc7fcbd743d20', 'width': 364}, {'height': 302, 'url': 'https://i.scdn.co/image/6fc200a8c4626352a74920ed8e21d4f6b05ef82c', 'width': 200}, {'height': 97, 'url': 'https://i.scdn.co/image/02f44d56f266de1f0f381dd719a1ad8b2de67fac', 'width': 64}], 'name': 'The Blakes', 'popularity': 9, 'type': 'artist', 'uri': 'spotify:artist:0HqBFsCRKEdhNRfh5e3sFD'}
# Updating artist: spotify:artist:3r3Rkuc4jmZHXgchgaXwnv
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3r3Rkuc4jmZHXgchgaXwnv'}, 'followers': {'href': None, 'total': 10136}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/3r3Rkuc4jmZHXgchgaXwnv', 'id': '3r3Rkuc4jmZHXgchgaXwnv', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb227d94621d5d8e0bf756cec6', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174227d94621d5d8e0bf756cec6', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178227d94621d5d8e0bf756cec6', 'width': 160}], 'name': 'Suzi', 'popularity': 43, 'type': 'artist', 'uri': 'spotify:artist:3r3Rkuc4jmZHXgchgaXwnv'}
# Updating artist: spotify:artist:4zWyV16jvkMJedeMhISJOw
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zWyV16jvkMJedeMhISJOw'}, 'followers': {'href': None, 'total': 4684}, 'genres': ['doo-wop', 'rhythm and blues'], 'href': 'https://api.spotify.com/v1/artists/4zWyV16jvkMJedeMhISJOw', 'id': '4zWyV16jvkMJedeMhISJOw', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2731d35221405c697a8042abe8c', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e021d35221405c697a8042abe8c', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048511d35221405c697a8042abe8c', 'width': 64}], 'name': 'The Mello-Kings', 'popularity': 22, 'type': 'artist', 'uri': 'spotify:artist:4zWyV16jvkMJedeMhISJOw'}
# Updating artist: spotify:artist:0LyfQWJT6nXafLPZqxe9Of
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'followers': {'href': None, 'total': 2247092}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb7462d94efa2db53abba8c003', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051747462d94efa2db53abba8c003', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1787462d94efa2db53abba8c003', 'width': 160}], 'name': 'Various Artists', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:1Fmb52lZ6Jv7FMWXXTPO3K
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Fmb52lZ6Jv7FMWXXTPO3K'}, 'followers': {'href': None, 'total': 729814}, 'genres': ['glam punk', 'rock'], 'href': 'https://api.spotify.com/v1/artists/1Fmb52lZ6Jv7FMWXXTPO3K', 'id': '1Fmb52lZ6Jv7FMWXXTPO3K', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb358cc74a410c5476802f9fb9', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174358cc74a410c5476802f9fb9', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178358cc74a410c5476802f9fb9', 'width': 160}], 'name': 'Joan Jett & the Blackhearts', 'popularity': 63, 'type': 'artist', 'uri': 'spotify:artist:1Fmb52lZ6Jv7FMWXXTPO3K'}
# Updating artist: spotify:artist:5MGoZUcMHAwTKzcXKKofQ9
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5MGoZUcMHAwTKzcXKKofQ9'}, 'followers': {'href': None, 'total': 15283}, 'genres': ['indie electropop'], 'href': 'https://api.spotify.com/v1/artists/5MGoZUcMHAwTKzcXKKofQ9', 'id': '5MGoZUcMHAwTKzcXKKofQ9', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb4bc7e0767bdce6727dbadea7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051744bc7e0767bdce6727dbadea7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1784bc7e0767bdce6727dbadea7', 'width': 160}], 'name': 'Riah', 'popularity': 34, 'type': 'artist', 'uri': 'spotify:artist:5MGoZUcMHAwTKzcXKKofQ9'}
# Updating artist: spotify:artist:5BTlwnHtDmzpMj0URbp4Ur
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5BTlwnHtDmzpMj0URbp4Ur'}, 'followers': {'href': None, 'total': 26923}, 'genres': ['glitch hop', 'halftime dnb', 'purple sound'], 'href': 'https://api.spotify.com/v1/artists/5BTlwnHtDmzpMj0URbp4Ur', 'id': '5BTlwnHtDmzpMj0URbp4Ur', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebd2db2420be519f1f0c5a7bad', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174d2db2420be519f1f0c5a7bad', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178d2db2420be519f1f0c5a7bad', 'width': 160}], 'name': 'MiM0SA', 'popularity': 29, 'type': 'artist', 'uri': 'spotify:artist:5BTlwnHtDmzpMj0URbp4Ur'}
# Processed 50 of 563 artists.
# Updating artist: spotify:artist:07VmOvmuBp9G0gb8BTrpn0
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/07VmOvmuBp9G0gb8BTrpn0'}, 'followers': {'href': None, 'total': 596816}, 'genres': ['dirty south rap'], 'href': 'https://api.spotify.com/v1/artists/07VmOvmuBp9G0gb8BTrpn0', 'id': '07VmOvmuBp9G0gb8BTrpn0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb0df2579929cbf82f4721422c', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051740df2579929cbf82f4721422c', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1780df2579929cbf82f4721422c', 'width': 160}], 'name': 'Mike Jones', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:07VmOvmuBp9G0gb8BTrpn0'}
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:5TGdkTyHliaYLHPGxqcSUt
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TGdkTyHliaYLHPGxqcSUt'}, 'followers': {'href': None, 'total': 50742}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5TGdkTyHliaYLHPGxqcSUt', 'id': '5TGdkTyHliaYLHPGxqcSUt', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb76b0c833a68ada7ececd0fc6', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517476b0c833a68ada7ececd0fc6', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17876b0c833a68ada7ececd0fc6', 'width': 160}], 'name': 'OVERSTREET', 'popularity': 31, 'type': 'artist', 'uri': 'spotify:artist:5TGdkTyHliaYLHPGxqcSUt'}
# Updating artist: spotify:artist:0DxPHf2flBAcV2SnZPg3SV
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DxPHf2flBAcV2SnZPg3SV'}, 'followers': {'href': None, 'total': 180954}, 'genres': ['indiecoustica', 'singer-songwriter pop'], 'href': 'https://api.spotify.com/v1/artists/0DxPHf2flBAcV2SnZPg3SV', 'id': '0DxPHf2flBAcV2SnZPg3SV', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb69ad6fb6d1c534eb75d5bea7', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517469ad6fb6d1c534eb75d5bea7', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17869ad6fb6d1c534eb75d5bea7', 'width': 160}], 'name': 'Jake Scott', 'popularity': 61, 'type': 'artist', 'uri': 'spotify:artist:0DxPHf2flBAcV2SnZPg3SV'}
# Updating artist: spotify:artist:3VZXmYrB3MxMfTZKIVZA1J
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3VZXmYrB3MxMfTZKIVZA1J'}, 'followers': {'href': None, 'total': 516222}, 'genres': ['axe', 'pagode', 'pagode baiano'], 'href': 'https://api.spotify.com/v1/artists/3VZXmYrB3MxMfTZKIVZA1J', 'id': '3VZXmYrB3MxMfTZKIVZA1J', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebf05da84d8dd347fe8b742585', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174f05da84d8dd347fe8b742585', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178f05da84d8dd347fe8b742585', 'width': 160}], 'name': 'XANDDY HARMONIA', 'popularity': 52, 'type': 'artist', 'uri': 'spotify:artist:3VZXmYrB3MxMfTZKIVZA1J'}
# Updating artist: spotify:artist:3cgO5CdhEHKMxldjZlP5ix
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cgO5CdhEHKMxldjZlP5ix'}, 'followers': {'href': None, 'total': 91426}, 'genres': ['adult standards', 'cowboy western', 'easy listening', 'rock-and-roll'], 'href': 'https://api.spotify.com/v1/artists/3cgO5CdhEHKMxldjZlP5ix', 'id': '3cgO5CdhEHKMxldjZlP5ix', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d2891e560fc2f97a5ab76d9e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d2891e560fc2f97a5ab76d9e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d2891e560fc2f97a5ab76d9e', 'width': 64}], 'name': 'Frankie Laine', 'popularity': 40, 'type': 'artist', 'uri': 'spotify:artist:3cgO5CdhEHKMxldjZlP5ix'}
# Updating artist: spotify:artist:5QLtWvBrVaf6WjKCBD1nrx
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5QLtWvBrVaf6WjKCBD1nrx'}, 'followers': {'href': None, 'total': 7}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5QLtWvBrVaf6WjKCBD1nrx', 'id': '5QLtWvBrVaf6WjKCBD1nrx', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ef7521e31fd215c6a25bbcc2', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ef7521e31fd215c6a25bbcc2', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ef7521e31fd215c6a25bbcc2', 'width': 64}], 'name': 'Plata Billete Tonos', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:5QLtWvBrVaf6WjKCBD1nrx'}
# Updating artist: spotify:artist:6GH0NzpthMGxu1mcfAkOde
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6GH0NzpthMGxu1mcfAkOde'}, 'followers': {'href': None, 'total': 219016}, 'genres': ['neon pop punk', 'pop punk'], 'href': 'https://api.spotify.com/v1/artists/6GH0NzpthMGxu1mcfAkOde', 'id': '6GH0NzpthMGxu1mcfAkOde', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb9e362c45d22e594e532969d9', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051749e362c45d22e594e532969d9', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1789e362c45d22e594e532969d9', 'width': 160}], 'name': 'Hellogoodbye', 'popularity': 44, 'type': 'artist', 'uri': 'spotify:artist:6GH0NzpthMGxu1mcfAkOde'}
# Updating artist: spotify:artist:0e6qzpphJHtObTSwD75mi0
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0e6qzpphJHtObTSwD75mi0'}, 'followers': {'href': None, 'total': 309648}, 'genres': ['deep euro house', 'new french touch'], 'href': 'https://api.spotify.com/v1/artists/0e6qzpphJHtObTSwD75mi0', 'id': '0e6qzpphJHtObTSwD75mi0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb44d3351084df88ad865b1ccb', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517444d3351084df88ad865b1ccb', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17844d3351084df88ad865b1ccb', 'width': 160}], 'name': 'The Avener', 'popularity': 59, 'type': 'artist', 'uri': 'spotify:artist:0e6qzpphJHtObTSwD75mi0'}
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:6JbZAYSfnXrYTnt3wSYBro
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JbZAYSfnXrYTnt3wSYBro'}, 'followers': {'href': None, 'total': 19418}, 'genres': ['pop r&b'], 'href': 'https://api.spotify.com/v1/artists/6JbZAYSfnXrYTnt3wSYBro', 'id': '6JbZAYSfnXrYTnt3wSYBro', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebdd381663ab7adb096ef8f62a', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174dd381663ab7adb096ef8f62a', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178dd381663ab7adb096ef8f62a', 'width': 160}], 'name': 'Chiae', 'popularity': 29, 'type': 'artist', 'uri': 'spotify:artist:6JbZAYSfnXrYTnt3wSYBro'}
# Updating artist: spotify:artist:3qM2kgxt87sXgP2ytxZZv2
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qM2kgxt87sXgP2ytxZZv2'}, 'followers': {'href': None, 'total': 35693}, 'genres': ['british singer-songwriter', 'rva indie'], 'href': 'https://api.spotify.com/v1/artists/3qM2kgxt87sXgP2ytxZZv2', 'id': '3qM2kgxt87sXgP2ytxZZv2', 'images': [{'height': 1000, 'url': 'https://i.scdn.co/image/1b507f599929d3599f337fc509f6cf3fbfc7e523', 'width': 1000}, {'height': 640, 'url': 'https://i.scdn.co/image/c7a471bd69ceb708c75a0b4e1748d2ffa7d08293', 'width': 640}, {'height': 200, 'url': 'https://i.scdn.co/image/9752e37d9d8e4b5d8ab73d26f340a370164600bc', 'width': 200}, {'height': 64, 'url': 'https://i.scdn.co/image/b92bf00c6ad091873f90ef7bd969ea81b0babb06', 'width': 64}], 'name': 'Flo Morrissey', 'popularity': 35, 'type': 'artist', 'uri': 'spotify:artist:3qM2kgxt87sXgP2ytxZZv2'}
# Updating artist: spotify:artist:2Lgxm04e7pNjXnFG5J6B0V
# ...
# Updating artist: spotify:artist:5rG61ghWZ2R4TDvCO7d0jw
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5rG61ghWZ2R4TDvCO7d0jw'}, 'followers': {'href': None, 'total': 44811}, 'genres': ['chinese r&b', 'malaysian mandopop', 'mandopop'], 'href': 'https://api.spotify.com/v1/artists/5rG61ghWZ2R4TDvCO7d0jw', 'id': '5rG61ghWZ2R4TDvCO7d0jw', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb7a093024936d140ea504d430', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051747a093024936d140ea504d430', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1787a093024936d140ea504d430', 'width': 160}], 'name': 'Z-Chen', 'popularity': 45, 'type': 'artist', 'uri': 'spotify:artist:5rG61ghWZ2R4TDvCO7d0jw'}
# Updating artist: spotify:artist:1YwBQZlsK015NpwaF8gpd9
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1YwBQZlsK015NpwaF8gpd9'}, 'followers': {'href': None, 'total': 37445}, 'genres': ['c-pop', 'chinese indie rock', 'classic mandopop'], 'href': 'https://api.spotify.com/v1/artists/1YwBQZlsK015NpwaF8gpd9', 'id': '1YwBQZlsK015NpwaF8gpd9', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b9a7b4e86c987480ed1e1929', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b9a7b4e86c987480ed1e1929', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b9a7b4e86c987480ed1e1929', 'width': 64}], 'name': '崔健', 'popularity': 27, 'type': 'artist', 'uri': 'spotify:artist:1YwBQZlsK015NpwaF8gpd9'}
# Updating artist: spotify:artist:67HW6PKDXtSXN6ANTEQemN
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/67HW6PKDXtSXN6ANTEQemN'}, 'followers': {'href': None, 'total': 7134}, 'genres': ['latin jazz', 'musica tradicional cubana', 'salsa international'], 'href': 'https://api.spotify.com/v1/artists/67HW6PKDXtSXN6ANTEQemN', 'id': '67HW6PKDXtSXN6ANTEQemN', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735b996a6a913cab3bc468f562', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e025b996a6a913cab3bc468f562', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048515b996a6a913cab3bc468f562', 'width': 64}], 'name': 'Tito Rodriguez & His Orchestra', 'popularity': 30, 'type': 'artist', 'uri': 'spotify:artist:67HW6PKDXtSXN6ANTEQemN'}
# Updating artist: spotify:artist:6JGPCu8A5iBnvYuGx5vKP0
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6JGPCu8A5iBnvYuGx5vKP0'}, 'followers': {'href': None, 'total': 2020}, 'genres': ['vintage hollywood'], 'href': 'https://api.spotify.com/v1/artists/6JGPCu8A5iBnvYuGx5vKP0', 'id': '6JGPCu8A5iBnvYuGx5vKP0', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d9408e285ca712f9ee67609f', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d9408e285ca712f9ee67609f', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d9408e285ca712f9ee67609f', 'width': 64}], 'name': "Donald O'Connor", 'popularity': 32, 'type': 'artist', 'uri': 'spotify:artist:6JGPCu8A5iBnvYuGx5vKP0'}
# Updating artist: spotify:artist:23m7tUHLULVyBAAIYHbsgT
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/23m7tUHLULVyBAAIYHbsgT'}, 'followers': {'href': None, 'total': 29781}, 'genres': ['k-indie', 'korean city pop'], 'href': 'https://api.spotify.com/v1/artists/23m7tUHLULVyBAAIYHbsgT', 'id': '23m7tUHLULVyBAAIYHbsgT', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2737b92cfac5b2c27330d866156', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02bc769a5f37fdac6439f4a37a', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048517b92cfac5b2c27330d866156', 'width': 64}], 'name': 'HUS', 'popularity': 48, 'type': 'artist', 'uri': 'spotify:artist:23m7tUHLULVyBAAIYHbsgT'}
# Updating artist: spotify:artist:5kPedB70NoaucwCvU7awih
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kPedB70NoaucwCvU7awih'}, 'followers': {'href': None, 'total': 223}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/5kPedB70NoaucwCvU7awih', 'id': '5kPedB70NoaucwCvU7awih', 'images': [], 'name': 'Artist Page Redirect Cleanup 2023', 'popularity': 5, 'type': 'artist', 'uri': 'spotify:artist:5kPedB70NoaucwCvU7awih'}
# Updating artist: spotify:artist:5XWv1p8oOhKmviB5vovWg1
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5XWv1p8oOhKmviB5vovWg1'}, 'followers': {'href': None, 'total': 80496}, 'genres': ['anime rock', 'j-division', 'vocaloid'], 'href': 'https://api.spotify.com/v1/artists/5XWv1p8oOhKmviB5vovWg1', 'id': '5XWv1p8oOhKmviB5vovWg1', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2730a4170870f743156e6c92806', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e020a4170870f743156e6c92806', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048510a4170870f743156e6c92806', 'width': 64}], 'name': 'Hitoshizuku and Yama', 'popularity': 39, 'type': 'artist', 'uri': 'spotify:artist:5XWv1p8oOhKmviB5vovWg1'}
# Processed 550 of 563 artists.
# Updating artist: spotify:artist:0OcclcP5o8VKH2TRqSY2A7
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OcclcP5o8VKH2TRqSY2A7'}, 'followers': {'href': None, 'total': 423163}, 'genres': ['canadian classical', 'canadian soundtrack', 'middle earth', 'orchestral soundtrack', 'scorecore', 'soundtrack'], 'href': 'https://api.spotify.com/v1/artists/0OcclcP5o8VKH2TRqSY2A7', 'id': '0OcclcP5o8VKH2TRqSY2A7', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb845fb635fad84bdcda4bf51f', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174845fb635fad84bdcda4bf51f', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178845fb635fad84bdcda4bf51f', 'width': 160}], 'name': 'Howard Shore', 'popularity': 65, 'type': 'artist', 'uri': 'spotify:artist:0OcclcP5o8VKH2TRqSY2A7'}
# Updating artist: spotify:artist:5FzSQmddi3XVt5zuvfGStF
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FzSQmddi3XVt5zuvfGStF'}, 'followers': {'href': None, 'total': 15011}, 'genres': ["children's music"], 'href': 'https://api.spotify.com/v1/artists/5FzSQmddi3XVt5zuvfGStF', 'id': '5FzSQmddi3XVt5zuvfGStF', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27398090948591471c229b5f5fa', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0298090948591471c229b5f5fa', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485198090948591471c229b5f5fa', 'width': 64}], 'name': 'Yo Gabba Gabba', 'popularity': 26, 'type': 'artist', 'uri': 'spotify:artist:5FzSQmddi3XVt5zuvfGStF'}
# Updating artist: spotify:artist:354bn1gKNGwig4UD80Lytn
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/354bn1gKNGwig4UD80Lytn'}, 'followers': {'href': None, 'total': 151965}, 'genres': ['albanian hip hop', 'albanian pop'], 'href': 'https://api.spotify.com/v1/artists/354bn1gKNGwig4UD80Lytn', 'id': '354bn1gKNGwig4UD80Lytn', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebbc8ddfa8da54adfa8030c604', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174bc8ddfa8da54adfa8030c604', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178bc8ddfa8da54adfa8030c604', 'width': 160}], 'name': '2Ton', 'popularity': 50, 'type': 'artist', 'uri': 'spotify:artist:354bn1gKNGwig4UD80Lytn'}
# Updating artist: spotify:artist:0DlVk18MAbEqGfTUzoVK41
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DlVk18MAbEqGfTUzoVK41'}, 'followers': {'href': None, 'total': 103}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0DlVk18MAbEqGfTUzoVK41', 'id': '0DlVk18MAbEqGfTUzoVK41', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2737f5d9054bdb2ee2e84967d7e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e027f5d9054bdb2ee2e84967d7e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048517f5d9054bdb2ee2e84967d7e', 'width': 64}], 'name': 'Samuel A. Ward', 'popularity': 14, 'type': 'artist', 'uri': 'spotify:artist:0DlVk18MAbEqGfTUzoVK41'}
# Updating artist: spotify:artist:0rG0AZBscc8S8q1ahIsasI
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0rG0AZBscc8S8q1ahIsasI'}, 'followers': {'href': None, 'total': 935020}, 'genres': ['bounce', 'crunk', 'dirty south rap', 'new orleans rap', 'southern hip hop'], 'href': 'https://api.spotify.com/v1/artists/0rG0AZBscc8S8q1ahIsasI', 'id': '0rG0AZBscc8S8q1ahIsasI', 'images': [{'height': 665, 'url': 'https://i.scdn.co/image/9b0979334be12f30b68cb95c7f9fee51133eeb33', 'width': 1000}, {'height': 425, 'url': 'https://i.scdn.co/image/845e9dd84ff3d56b5ad0fbdca55385adc0ddb67b', 'width': 640}, {'height': 133, 'url': 'https://i.scdn.co/image/f72591cf2178ad89d5b7d42d1a9d73d7273d0446', 'width': 200}, {'height': 43, 'url': 'https://i.scdn.co/image/78a4c82368fecc98b2f9ed201cf2d6e213104f25', 'width': 64}], 'name': 'JUVENILE', 'popularity': 58, 'type': 'artist', 'uri': 'spotify:artist:0rG0AZBscc8S8q1ahIsasI'}
# Updating artist: spotify:artist:58BWh3yJrluDugLv0QF0eC
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/58BWh3yJrluDugLv0QF0eC'}, 'followers': {'href': None, 'total': 45165}, 'genres': ['k-pop', 'korean pop', 'korean singer-songwriter'], 'href': 'https://api.spotify.com/v1/artists/58BWh3yJrluDugLv0QF0eC', 'id': '58BWh3yJrluDugLv0QF0eC', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2737ae18c6f8287fa3066c0224b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e023694e520c30f4eff71742f10', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851a2622af5f9c0f4cecf60646b', 'width': 64}], 'name': 'Lee So Ra', 'popularity': 41, 'type': 'artist', 'uri': 'spotify:artist:58BWh3yJrluDugLv0QF0eC'}
# Updating artist: spotify:artist:3tPQOjkxO3mrYrrgkTeXgH
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tPQOjkxO3mrYrrgkTeXgH'}, 'followers': {'href': None, 'total': 390813}, 'genres': ['modern bollywood'], 'href': 'https://api.spotify.com/v1/artists/3tPQOjkxO3mrYrrgkTeXgH', 'id': '3tPQOjkxO3mrYrrgkTeXgH', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebdd5c130b30b814d27620dfe4', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174dd5c130b30b814d27620dfe4', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178dd5c130b30b814d27620dfe4', 'width': 160}], 'name': 'Nikhita Gandhi', 'popularity': 69, 'type': 'artist', 'uri': 'spotify:artist:3tPQOjkxO3mrYrrgkTeXgH'}
# Updating artist: spotify:artist:6HtEIJH43LAZGQx6iNCqhg
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/6HtEIJH43LAZGQx6iNCqhg'}, 'followers': {'href': None, 'total': 81675}, 'genres': ['filmi', 'tamil pop'], 'href': 'https://api.spotify.com/v1/artists/6HtEIJH43LAZGQx6iNCqhg', 'id': '6HtEIJH43LAZGQx6iNCqhg', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27349efd458d9cf350e61cd99e8', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0249efd458d9cf350e61cd99e8', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485149efd458d9cf350e61cd99e8', 'width': 64}], 'name': 'Gana Bala', 'popularity': 53, 'type': 'artist', 'uri': 'spotify:artist:6HtEIJH43LAZGQx6iNCqhg'}
# Updating artist: spotify:artist:1fNhDktKNtf7g7COrlJguP
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1fNhDktKNtf7g7COrlJguP'}, 'followers': {'href': None, 'total': 116462}, 'genres': ['arab pop', 'belly dance', 'shaabi'], 'href': 'https://api.spotify.com/v1/artists/1fNhDktKNtf7g7COrlJguP', 'id': '1fNhDktKNtf7g7COrlJguP', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d7804aec7445ca81c4bf536a', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d7804aec7445ca81c4bf536a', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d7804aec7445ca81c4bf536a', 'width': 64}], 'name': 'Saad El Soghayar', 'popularity': 38, 'type': 'artist', 'uri': 'spotify:artist:1fNhDktKNtf7g7COrlJguP'}
# Updating artist: spotify:artist:4sOvsEM0ooH149joyEm7Wg
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sOvsEM0ooH149joyEm7Wg'}, 'followers': {'href': None, 'total': 145045}, 'genres': ['v-pop'], 'href': 'https://api.spotify.com/v1/artists/4sOvsEM0ooH149joyEm7Wg', 'id': '4sOvsEM0ooH149joyEm7Wg', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273caa7ef3c1e269ce6b12f6b3e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02caa7ef3c1e269ce6b12f6b3e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851caa7ef3c1e269ce6b12f6b3e', 'width': 64}], 'name': 'Lê Hiếu', 'popularity': 38, 'type': 'artist', 'uri': 'spotify:artist:4sOvsEM0ooH149joyEm7Wg'}
# Updating artist: spotify:artist:69HouC7BpXVxTAFwpckJHs
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/69HouC7BpXVxTAFwpckJHs'}, 'followers': {'href': None, 'total': 163495}, 'genres': ['chicago drill', 'chicago rap', 'drill'], 'href': 'https://api.spotify.com/v1/artists/69HouC7BpXVxTAFwpckJHs', 'id': '69HouC7BpXVxTAFwpckJHs', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2738c7088280478725886e302c1', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e028c7088280478725886e302c1', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048518c7088280478725886e302c1', 'width': 64}], 'name': 'La Capone', 'popularity': 41, 'type': 'artist', 'uri': 'spotify:artist:69HouC7BpXVxTAFwpckJHs'}
# Updating artist: spotify:artist:3VrAdkRvMBU7JxPURFda9l
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/3VrAdkRvMBU7JxPURFda9l'}, 'followers': {'href': None, 'total': 12494}, 'genres': ['korean city pop'], 'href': 'https://api.spotify.com/v1/artists/3VrAdkRvMBU7JxPURFda9l', 'id': '3VrAdkRvMBU7JxPURFda9l', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5ebd4f0693a0e590836ecbb3bae', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab67616100005174d4f0693a0e590836ecbb3bae', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f178d4f0693a0e590836ecbb3bae', 'width': 160}], 'name': 'KREAM', 'popularity': 16, 'type': 'artist', 'uri': 'spotify:artist:3VrAdkRvMBU7JxPURFda9l'}
# Updating artist: spotify:artist:0LyfQWJT6nXafLPZqxe9Of
# Data received from API: {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'followers': {'href': None, 'total': 2247092}, 'genres': [], 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb7462d94efa2db53abba8c003', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051747462d94efa2db53abba8c003', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1787462d94efa2db53abba8c003', 'width': 160}], 'name': 'Various Artists', 'popularity': 0, 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}

# %%
# path to database file
conn = create_connection("playlist_analysis.db")

if conn is not None:
    df_artists = pd.read_sql_query("SELECT * FROM artists;", conn)
else:
    print("Failed to establish a connection.")

missing = df_artists.isnull().sum()
print(missing)
# Out:
# artist_uri       0
# artist_name      0
# popularity     563
# followers      563
# genres         563
# dtype: int64
